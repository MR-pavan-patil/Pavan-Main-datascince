# %%
import pandas as pd

# %%
ipl=pd.read_csv("csv data files/matches.csv")

# %%
ipl.head().shape
# Out:
# (5, 18)

# %%
main=ipl.drop(["dl_applied", "umpire1","umpire2","umpire3","venue" ], axis=1)

# %%
main.sample(10)
# Out:
#       id    Season            city        date                        team1  \
# 296  297  IPL-2011         Chennai  18-05-2011          Chennai Super Kings
# 77    78  IPL-2008          Jaipur  01-05-2008             Rajasthan Royals
# 223  224  IPL-2010         Chennai  15-04-2010          Chennai Super Kings
# 320  321  IPL-2012      Chandigarh  12-04-2012                Pune Warriors
# 491  492  IPL-2014       Bangalore  11-05-2014  Royal Challengers Bangalore
# 615  616  IPL-2016   Visakhapatnam  10-05-2016          Sunrisers Hyderabad
# 476  477  IPL-2014             NaN  30-04-2014          Sunrisers Hyderabad
# 627  628  IPL-2016          Raipur  20-05-2016          Sunrisers Hyderabad
# 552  553  IPL-2015          Mumbai  03-05-2015             Rajasthan Royals
# 131  132  IPL-2009  Port Elizabeth  27-04-2009               Mumbai Indians
#
#                        team2                  toss_winner toss_decision  \
# ...

# %%
main["player_of_match"]
# Out:
# 0      Yuvraj Singh
# 1         SPD Smith
# 2           CA Lynn
# 3        GJ Maxwell
# 4         KM Jadhav
#            ...
# 751       HH Pandya
# 752        AS Yadav
# 753         RR Pant
# 754    F du Plessis
# 755       JJ Bumrah
# Name: player_of_match, Length: 756, dtype: object

# %%
main.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
main[(main["Season"]=="IPL-2016") & ( main["city"]=="Bangalore")].shape
# Out:
# (9, 13)

# %%
main["team1"].value_counts()
# Out:
# team1
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Delhi Capitals                   6
# Name: count, dtype: int64

# %%
main[(main["player_of_match"]=="AB de Villiers") &  (main["Season"]=="IPL-2018")]
# Out:
#        id    Season       city        date                        team1  \
# 654  7912  IPL-2018  Bengaluru  21-04-2018             Delhi Daredevils
# 680  7938  IPL-2018      Delhi  12-05-2018             Delhi Daredevils
# 686  7944  IPL-2018  Bengaluru  17-05-2018  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 654  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 680  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 686          Sunrisers Hyderabad          Sunrisers Hyderabad         field
#
#      result                       winner  win_by_runs  win_by_wickets  \
# 654  normal  Royal Challengers Bangalore            0               6
# 680  normal  Royal Challengers Bangalore            0               5
# 686  normal  Royal Challengers Bangalore           14               0
#
#     player_of_match
# 654  AB de Villiers
# 680  AB de Villiers
# 686  AB de Villiers

# %%
rcb=main[main["winner"]=="Royal Challengers Bangalore"]

# %%
rcb.shape
# Out:
# (84, 13)

# %%
Kohli=rcb[rcb["player_of_match"]=="V Kohli"]

# %%
Kohli[Kohli["city"] == "Bangalore"]
# Out:
#       id    Season       city        date                        team1  \
# 267  268  IPL-2011  Bangalore  29-04-2011  Royal Challengers Bangalore
# 400  401  IPL-2013  Bangalore  16-04-2013             Delhi Daredevils
# 431  432  IPL-2013  Bangalore  09-04-2013          Sunrisers Hyderabad
# 451  452  IPL-2013  Bangalore  18-05-2013  Royal Challengers Bangalore
# 610  611  IPL-2016  Bangalore  07-05-2016      Rising Pune Supergiants
# 625  626  IPL-2016  Bangalore  18-05-2016  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 267                Pune Warriors                Pune Warriors         field
# 400  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 431  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
# 451          Chennai Super Kings          Chennai Super Kings         field
# 610  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
main.head(100)
# Out:
#      id    Season        city        date                        team1  \
# 0     1  IPL-2017   Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1     2  IPL-2017        Pune  06-04-2017               Mumbai Indians
# 2     3  IPL-2017      Rajkot  07-04-2017                Gujarat Lions
# 3     4  IPL-2017      Indore  08-04-2017       Rising Pune Supergiant
# 4     5  IPL-2017   Bangalore  08-04-2017  Royal Challengers Bangalore
# ..  ...       ...         ...         ...                          ...
# 95   96  IPL-2008      Mumbai  14-05-2008          Chennai Super Kings
# 96   97  IPL-2008  Chandigarh  28-05-2008              Kings XI Punjab
# 97   98  IPL-2008       Delhi  15-05-2008             Delhi Daredevils
# 98   99  IPL-2008      Mumbai  16-05-2008        Kolkata Knight Riders
# 99  100  IPL-2008       Delhi  17-05-2008             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# ...

# %%
main[main["player_of_match"]=="B Kumar"]
# Out:
#       id    Season       city        date                team1  \
# 18    19  IPL-2017  Hyderabad  17-04-2017  Sunrisers Hyderabad
# 476  477  IPL-2014        NaN  30-04-2014  Sunrisers Hyderabad
# 486  487  IPL-2014  Ahmedabad  08-05-2014  Sunrisers Hyderabad
# 590  591  IPL-2016     Rajkot  21-04-2016        Gujarat Lions
# 609  610  IPL-2016  Hyderabad  06-05-2016        Gujarat Lions
#
#                    team2          toss_winner toss_decision  result  \
# 18       Kings XI Punjab      Kings XI Punjab         field  normal
# 476       Mumbai Indians       Mumbai Indians         field  normal
# 486     Rajasthan Royals     Rajasthan Royals         field  normal
# 590  Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 609  Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
#
#                   winner  win_by_runs  win_by_wickets player_of_match
# 18   Sunrisers Hyderabad            5               0         B Kumar
# ...

# %%
main[main["city"]=="Hyderabad"]
# Out:
#         id    Season       city        date                  team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017    Sunrisers Hyderabad
# 5        6  IPL-2017  Hyderabad  09-04-2017          Gujarat Lions
# 18      19  IPL-2017  Hyderabad  17-04-2017    Sunrisers Hyderabad
# 20      21  IPL-2017  Hyderabad  19-04-2017    Sunrisers Hyderabad
# 35      36  IPL-2017  Hyderabad  30-04-2017    Sunrisers Hyderabad
# ..     ...       ...        ...         ...                    ...
# 725  11321  IPL-2019  Hyderabad  14-04-2019         Delhi Capitals
# 728  11324  IPL-2019  Hyderabad  17-04-2019    Chennai Super Kings
# 733  11329  IPL-2019  Hyderabad  21-04-2019  Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019    Sunrisers Hyderabad
# 755  11415  IPL-2019  Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
main["city"].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
main[main["city"]=="Abu Dhabi"]
# Out:
#       id    Season       city        date                        team1  \
# 457  458  IPL-2014  Abu Dhabi  16-04-2014        Kolkata Knight Riders
# 459  460  IPL-2014  Abu Dhabi  18-04-2014          Chennai Super Kings
# 460  461  IPL-2014  Abu Dhabi  18-04-2014          Sunrisers Hyderabad
# 464  465  IPL-2014  Abu Dhabi  21-04-2014          Chennai Super Kings
# 470  471  IPL-2014  Abu Dhabi  26-04-2014  Royal Challengers Bangalore
# 471  472  IPL-2014  Abu Dhabi  26-04-2014              Kings XI Punjab
# 475  476  IPL-2014  Abu Dhabi  29-04-2014             Rajasthan Royals
#
#                      team2            toss_winner toss_decision  result  \
# 457         Mumbai Indians  Kolkata Knight Riders           bat  normal
# 459        Kings XI Punjab    Chennai Super Kings           bat  normal
# 460       Rajasthan Royals       Rajasthan Royals         field  normal
# 464       Delhi Daredevils    Chennai Super Kings           bat  normal
# ...

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   winner           752 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  752 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 76.9+ KB

# %%
# main["id"]=main["id"].astype(float)

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   winner           752 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  752 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 76.9+ KB

# %%
main.sample(5)
# Out:
#         id    Season       city        date                  team1  \
# 485    486  IPL-2014    Cuttack  07-05-2014        Kings XI Punjab
# 720  11316  IPL-2019     Jaipur  11-04-2019       Rajasthan Royals
# 697  11138  IPL-2019    Kolkata  24-03-2019    Sunrisers Hyderabad
# 385    386  IPL-2013    Chennai  06-04-2013         Mumbai Indians
# 452    453  IPL-2013  Hyderabad  19-05-2013  Kolkata Knight Riders
#
#                      team2            toss_winner toss_decision  result  \
# 485    Chennai Super Kings    Chennai Super Kings         field  normal
# 720    Chennai Super Kings    Chennai Super Kings         field  normal
# 697  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 385    Chennai Super Kings         Mumbai Indians           bat  normal
# 452    Sunrisers Hyderabad  Kolkata Knight Riders           bat  normal
#
#                     winner  win_by_runs  win_by_wickets player_of_match
# ...

# %%
per_city=main["city"].value_counts()

# %%
main.shape
# Out:
# (756, 13)

# %%
main.shape
# Out:
# (756, 13)

# %%
main["player_of_match"]=main["player_of_match"].replace("RR Pant","rider")

# %%
main.shape
# Out:
# (756, 13)

# %% [markdown]
# main[main["player_of_match"]=="rider"].shape

# %%
 winer=main[["win_by_runs","winner"]]

# %%
most_wins=winer.sort_values("win_by_runs",ascending=False)

# %%
most_wins["winner"].unique()
# Out:
# array(['Mumbai Indians', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Sunrisers Hyderabad', 'Kings XI Punjab',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Delhi Daredevils',
#        'Deccan Chargers', 'Rising Pune Supergiant', 'Delhi Capitals',
#        'Pune Warriors', 'Rising Pune Supergiants', 'Kochi Tuskers Kerala',
#        'Gujarat Lions', nan], dtype=object)

# %%
main[main["player_of_match"]=="rider"]
# Out:
#         id    Season           city        date                team1  \
# 40      41  IPL-2017          Delhi  04-05-2017        Gujarat Lions
# 606    607  IPL-2016         Rajkot  03-05-2016        Gujarat Lions
# 667   7925  IPL-2018          Delhi  02-05-2018     Delhi Daredevils
# 698  11139  IPL-2019         Mumbai  24-03-2019       Delhi Capitals
# 735  11331  IPL-2019         Jaipur  22-04-2019     Rajasthan Royals
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019  Sunrisers Hyderabad
#
#                 team2       toss_winner toss_decision  result  \
# 40   Delhi Daredevils  Delhi Daredevils         field  normal
# 606  Delhi Daredevils  Delhi Daredevils         field  normal
# 667  Rajasthan Royals  Rajasthan Royals         field  normal
# 698    Mumbai Indians    Mumbai Indians         field  normal
# 735    Delhi Capitals    Delhi Capitals         field  normal
# 753    Delhi Capitals    Delhi Capitals         field  normal
#
# ...

# %%
data = main

# %%
data["date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 756 entries, 0 to 755
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 756 non-null    object
# dtypes: object(1)
# memory usage: 6.0+ KB

# %%
data["date"].astype("datetime(ns)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 data["date"].astype("datetime(ns)")
#
# File c:\Users\pavan\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\pavan\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
ipl
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
ipl.sample(5)
# Out:
#         id    Season       city        date                   team1  \
# 350    351  IPL-2012       Pune  03-05-2012          Mumbai Indians
# 175    176  IPL-2010     Mumbai  13-03-2010          Mumbai Indians
# 725  11321  IPL-2019  Hyderabad  14-04-2019          Delhi Capitals
# 32      33  IPL-2017       Pune  29-04-2017  Rising Pune Supergiant
# 602    603  IPL-2016  Hyderabad  30-04-2016     Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 350                Pune Warriors               Mumbai Indians           bat
# 175             Rajasthan Royals               Mumbai Indians           bat
# 725          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 32   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 602  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#      result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
main=ipl.drop(["umpire1","umpire2","umpire3","dl_applied"],axis=1)

# %%
main
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
main[main["winner"]=="Royal Challengers Bangalore"]
# Out:
#         id    Season       city        date                        team1  \
# 4        5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 19      20  IPL-2017     Rajkot  18-04-2017  Royal Challengers Bangalore
# 54      55  IPL-2017      Delhi  14-05-2017  Royal Challengers Bangalore
# 62      63  IPL-2008     Mumbai  20-04-2008               Mumbai Indians
# 79      80  IPL-2008  Hyderabad  25-05-2008              Deccan Chargers
# ..     ...       ...        ...         ...                          ...
# 723  11319  IPL-2019     Mohali  13-04-2019              Kings XI Punjab
# 730  11326  IPL-2019    Kolkata  19-04-2019  Royal Challengers Bangalore
# 734  11330  IPL-2019  Bengaluru  21-04-2019  Royal Challengers Bangalore
# 737  11333  IPL-2019  Bengaluru  24-04-2019  Royal Challengers Bangalore
# 749  11345  IPL-2019  Bengaluru  04-05-2019          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
main
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
main.shape
# Out:
# (756, 13)

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   winner           752 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  752 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 76.9+ KB

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20316\2044643567.py in ?()
# ----> 1 main.unique()
#
# c:\Users\pavan\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
main
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   winner           752 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  752 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 76.9+ KB

# %%
main[main["city"]=="Hyderabad"]
# Out:
#         id    Season       city        date                  team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017    Sunrisers Hyderabad
# 5        6  IPL-2017  Hyderabad  09-04-2017          Gujarat Lions
# 18      19  IPL-2017  Hyderabad  17-04-2017    Sunrisers Hyderabad
# 20      21  IPL-2017  Hyderabad  19-04-2017    Sunrisers Hyderabad
# 35      36  IPL-2017  Hyderabad  30-04-2017    Sunrisers Hyderabad
# ..     ...       ...        ...         ...                    ...
# 725  11321  IPL-2019  Hyderabad  14-04-2019         Delhi Capitals
# 728  11324  IPL-2019  Hyderabad  17-04-2019    Chennai Super Kings
# 733  11329  IPL-2019  Hyderabad  21-04-2019  Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019    Sunrisers Hyderabad
# 755  11415  IPL-2019  Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
hyd=main[(main["city"]=="Hyderabad")  & (main["winner"]=="Sunrisers Hyderabad") & (main["player_of_match"]=="DA Warner")]

# %%
hyd.shape
# Out:
# (8, 13)

# %%
Visakhapatnam=main[main["city"]=="Visakhapatnam"]

# %%
main["city"].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
data=main["player_of_match"].value_counts()

# %%
data
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# RG Sharma         17
# DA Warner         17
#                   ..
# Imran Tahir        1
# K Paul             1
# K Ahmed            1
# S Gill             1
# S Hetmyer          1
# Name: count, Length: 226, dtype: int64

# %%
main.sample(5)
# Out:
#       id    Season        city        date             team1  \
# 512  513  IPL-2014      Mumbai  25-05-2014  Rajasthan Royals
# 327  328  IPL-2012      Jaipur  17-04-2012   Deccan Chargers
# 539  540  IPL-2015   Ahmedabad  24-04-2015  Rajasthan Royals
# 101  102  IPL-2008   Hyderabad  18-05-2008    Mumbai Indians
# 192  193  IPL-2010  Chandigarh  24-03-2010  Rajasthan Royals
#
#                            team2                  toss_winner toss_decision  \
# 512               Mumbai Indians               Mumbai Indians         field
# 327             Rajasthan Royals              Deccan Chargers           bat
# 539  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 101              Deccan Chargers              Deccan Chargers         field
# 192              Kings XI Punjab              Kings XI Punjab         field
#
#      result                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
main[main["date"].between("17-04-2012" ,"25-05-2014" )]
# Out:
#         id    Season       city        date                        team1  \
# 17      18  IPL-2017      Delhi  17-04-2017             Delhi Daredevils
# 18      19  IPL-2017  Hyderabad  17-04-2017          Sunrisers Hyderabad
# 19      20  IPL-2017     Rajkot  18-04-2017  Royal Challengers Bangalore
# 20      21  IPL-2017  Hyderabad  19-04-2017          Sunrisers Hyderabad
# 21      22  IPL-2017     Indore  20-04-2017              Kings XI Punjab
# ..     ...       ...        ...         ...                          ...
# 734  11330  IPL-2019  Bengaluru  21-04-2019  Royal Challengers Bangalore
# 735  11331  IPL-2019     Jaipur  22-04-2019             Rajasthan Royals
# 736  11332  IPL-2019    Chennai  23-04-2019          Sunrisers Hyderabad
# 737  11333  IPL-2019  Bengaluru  24-04-2019  Royal Challengers Bangalore
# 738  11334  IPL-2019    Kolkata  25-04-2019        Kolkata Knight Riders
#
#                      team2          toss_winner toss_decision  result  \
# ...
