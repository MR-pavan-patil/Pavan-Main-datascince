# %% [markdown]
# ODI CRICKET

# %% [markdown]
# IMPORTING LABRARIES

# %%
import pandas as pd
print("Pandas imported successfully.")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
# Out:
# Pandas imported successfully.

# %% [markdown]
# # loda data set

# %%
data=pd.read_csv("csv data files/ODI.csv")
print("data set loaded sussfully")
print(f"ODI dataset shape{data.shape}")
# Out:
# data set loaded sussfully
# ODI dataset shape(1540, 17)

# %%
print("=="*40)
print(f"sample data of OdI data set")
print("=="*40)
data.sample(10)
# Out:
# ...
# sample data of OdI data set
# ...
#            player_name    role  total_runs             strike_rate  \
# 1209       BA Langston  Batter          21   9.545.454.545.454.540
# 407      CR Brathwaite  Batter         527   8.597.063.621.533.440
# 31            AJ Finch  Batter        5188   8.456.397.718.011.410
# 137          H Klaasen  Batter        1977   1.150.087.260.034.900
# 461       Ayesha Zafar  Batter         407   5.327.225.130.890.050
# 331       Pargat Singh  Batter         722   7.763.440.860.215.050
# 192      Nasir Jamshed  Batter        1418   7.343.345.416.882.440
# 401           CA Henry  Batter         537   7.638.691.322.901.840
# 794   Mudassar Bukhari  Batter         126   6.923.076.923.076.920
# 907        J Sumerauer  Batter          84  11.351.351.351.351.300
#
#       total_balls_faced  total_wickets_taken  total_runs_conceded  \
# 1209                 22                    2                   70
# ...

# %%
data["role"].unique()
# Out:
# array(['Batter'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1540 entries, 0 to 1539
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   player_name               1540 non-null   object
#  1   role                      1540 non-null   object
#  2   total_runs                1540 non-null   int64
#  3   strike_rate               1540 non-null   object
#  4   total_balls_faced         1540 non-null   int64
#  5   total_wickets_taken       1540 non-null   int64
#  6   total_runs_conceded       1540 non-null   int64
#  7   total_overs_bowled        1540 non-null   int64
#  8   total_matches_played      1540 non-null   int64
#  9   matches_played_as_batter  1540 non-null   int64
#  10  matches_played_as_bowler  1540 non-null   int64
#  11  matches_won               1540 non-null   int64
#  12  matches_lost              1540 non-null   int64
#  13  player_of_match_awards    1540 non-null   int64
# ...

# %% [markdown]
# batters data

# %%
batter=data[data["role"]=="Batter"]

# %%
batter
# Out:
#            player_name    role  total_runs            strike_rate  \
# 0              V Kohli  Batter       13784  9.170.381.212.161.530
# 1        KC Sangakkara  Batter       11618  7.939.046.057.127.230
# 2            RG Sharma  Batter       10646  9.035.817.348.497.700
# 3             MS Dhoni  Batter       10274  8.497.932.175.351.530
# 4       AB de Villiers  Batter        9435  9.944.139.966.273.180
# ...                ...     ...         ...                    ...
# 1535        C Sakariya  Batter           0                    0.0
# 1536  Shahriar Hossain  Batter           0                    0.0
# 1537      Salman Faris  Batter           0                    0.0
# 1538  Haseebullah Khan  Batter           0                    0.0
# 1539  Syeda Aroob Shah  Batter           0                    0.0
#
#       total_balls_faced  total_wickets_taken  total_runs_conceded  \
# 0                 15031                    7                  681
# ...

# %%
batter.shape
# Out:
# (1540, 17)

# %%
appne=data[data["team"]=="India"]

# %%
print(appne["strike_rate"].max())
# Out:
# 995.505.617.977.528
