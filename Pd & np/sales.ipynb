# %%
import pandas as pd

# %%
df=pd.read_csv("csv data files/sales_data.csv")

# %%
df
# Out:
#          order_id        date   region sales_channel customer_segment  \
# 0    ORD202313278  2023-10-09    North        Online   Small Business
# 1    ORD202387397  2024-03-08    South        Online       Individual
# 2    ORD202383563  2023-07-23    South         Store        Corporate
# 3    ORD202410851  2023-06-13     East         Store       Individual
# 4    ORD202354118  2023-04-15     East        Online        Corporate
# ..            ...         ...      ...           ...              ...
# 495  ORD202354663  2023-07-01    North        Online       Individual
# 496  ORD202324538  2024-06-22     East        Online   Small Business
# 497  ORD202486810  2023-04-14    South         Store       Individual
# 498  ORD202493789  2024-05-13  Central        Online   Small Business
# 499  ORD202439260  2024-11-12     East         Store   Small Business
#
#           category        product  quantity  unit_price  total_sales  \
# ...

# %%
labtop=df[df["product"]=="Laptop"]

# %%
labtop
# Out:
#          order_id        date   region sales_channel customer_segment  \
# 1    ORD202387397  2024-03-08    South        Online       Individual
# 47   ORD202327601  2023-09-28  Central         Phone       Individual
# 51   ORD202483519  2023-01-10    South         Phone   Small Business
# 305  ORD202393616  2023-08-27     East         Store   Small Business
# 393  ORD202453463  2024-03-16     East        Online       Individual
# 429  ORD202392074  2024-04-15     West        Online        Corporate
# 478  ORD202328322  2023-05-05    South        Online       Individual
# 493  ORD202433010  2024-05-17    South        Online   Small Business
#
#         category product  quantity  unit_price  total_sales  discount_percent  \
# 1    Electronics  Laptop        19      379.95      7219.05              8.34
# 47   Electronics  Laptop        35     1373.53     48073.55             17.80
# 51   Electronics  Laptop        27      981.91     26511.57             16.13
# ...

# %%
df.sample(8)
# Out:
#          order_id        date   region sales_channel customer_segment  \
# 266  ORD202426821  2024-07-18    South        Online        Corporate
# 332  ORD202349107  2024-04-19  Central         Store        Corporate
# 115  ORD202344687  2024-11-07    South        Online   Small Business
# 113  ORD202378494  2024-01-25  Central         Store        Corporate
# 178  ORD202494323  2023-02-01     West         Store   Small Business
# 140  ORD202423154  2024-03-26    North         Store   Small Business
# 493  ORD202433010  2024-05-17    South        Online   Small Business
# 215  ORD202318109  2024-04-06    North         Phone   Small Business
#
#         category      product  quantity  unit_price  total_sales  \
# 266       Sports    Dumbbells        48      221.26     10620.48
# 332       Sports    Dumbbells        24      215.21      5165.04
# 115  Electronics   Smartphone        13     1839.67     23915.71
# 113        Books       Comics        28       13.89       388.92
# ...

# %%
df["region"].unique()
# Out:
# array(['North', 'South', 'East', 'Central', 'West'], dtype=object)

# %%
labtop[labtop["region"]=="East"]["total_sales"].sum()
# Out:
# np.float64(56928.979999999996)

# %%
labtop.groupby("region"),["East"]== "total_sales".sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 labtop.groupby("region"),["East"]== "total_sales".sum()
#
# AttributeError: 'str' object has no attribute 'sum'

# %%
east=df[(df["region"]=="East") & (df["product"]=="Laptop")]

# %%
east["total_sales"].sum()
# Out:
# np.float64(56928.979999999996)

# %%
df.sample(10)
# Out:
#          order_id        date   region sales_channel customer_segment  \
# 350  ORD202451973  2023-07-28    North         Store   Small Business
# 393  ORD202453463  2024-03-16     East        Online       Individual
# 469  ORD202386122  2023-04-08     West         Phone       Individual
# 345  ORD202316755  2023-10-02    North         Phone       Individual
# 442  ORD202396298  2023-11-05  Central         Phone       Individual
# 171  ORD202353713  2023-09-07    North        Online   Small Business
# 49   ORD202442914  2023-02-22    North         Store       Individual
# 324  ORD202399167  2023-07-30    North         Store   Small Business
# 362  ORD202484055  2023-09-07    North         Store   Small Business
# 341  ORD202463511  2023-06-02  Central        Online        Corporate
#
#         category      product  quantity  unit_price  total_sales  \
# 350         Food    Beverages         3       29.41        88.23
# ...

# %%
df["customer_segment"].unique()
# Out:
# array(['Small Business', 'Individual', 'Corporate'], dtype=object)

# %%
df.groupby("customer_segment")[["category"][]

# %%
smallB=df[df["customer_segment"]=="Small Business"]

# %%
smallB
# Out:
#          order_id        date   region sales_channel customer_segment  \
# 0    ORD202313278  2023-10-09    North        Online   Small Business
# 5    ORD202415695  2024-04-15    North         Store   Small Business
# 6    ORD202492397  2024-09-25    South         Phone   Small Business
# 9    ORD202397841  2023-10-01    South         Phone   Small Business
# 13   ORD202428726  2023-09-29  Central         Phone   Small Business
# ..            ...         ...      ...           ...              ...
# 492  ORD202484403  2024-07-31     West        Online   Small Business
# 493  ORD202433010  2024-05-17    South        Online   Small Business
# 496  ORD202324538  2024-06-22     East        Online   Small Business
# 498  ORD202493789  2024-05-13  Central        Online   Small Business
# 499  ORD202439260  2024-11-12     East         Store   Small Business
#
#           category         product  quantity  unit_price  total_sales  \
# ...

# %%
a=smallB.groupby("product")["total_sales"].sum()

# %%
a
# Out:
# product
# Action Figures         14274.39
# Basketball             13049.36
# Bedding                33555.40
# Beverages               3342.84
# Board Games             7632.43
# Building Blocks         9515.20
# Coffee                  3248.86
# Comics                  7612.74
# Decor                  66377.67
# Dolls                   7457.18
# Dress                  12064.46
# Dumbbells              12610.29
# Educational             5014.47
# Fiction                 2814.51
# Football               23608.53
# Fresh Produce           2825.99
# Frozen Food             5989.42
# Furniture              72126.92
# Gardening Tools        38417.42
# Headphones            182281.10
# Jacket                 12776.16
# Jeans                  31154.10
# Kitchen Appliances     37028.87
# Laptop                137536.31
# Magazines               2680.55
# Non-Fiction             3642.66
# Puzzles                 6449.10
# Shoes                  15923.43
# Smart Watch           105121.69
# ...

# %%
maxsales  =     a.max()

# %%
maxsales
# Out:
# np.float64(228284.96000000002)

# %%
a[a == maxsales]
# Out:
# product
# Smartphone    228284.96
# Name: total_sales, dtype: float64

# %%
smallB["product"].value_counts()
# Out:
# product
# Furniture             10
# Snacks                10
# Jeans                  8
# Smartphone             8
# Frozen Food            8
# Comics                 8
# Decor                  7
# Shoes                  7
# Football               6
# Tablet                 6
# Headphones             6
# Fresh Produce          6
# Yoga Mat               6
# Non-Fiction            6
# Action Figures         5
# Dress                  5
# Basketball             5
# Smart Watch            5
# Beverages              5
# Tennis Racket          5
# Educational            5
# Fiction                4
# Dumbbells              4
# Bedding                4
# Board Games            4
# Coffee                 4
# Gardening Tools        4
# Kitchen Appliances     4
# Jacket                 3
# Laptop                 3
# Dolls                  3
# Puzzles                3
# Building Blocks        3
# Magazines              2
# T-Shirt                1
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#          order_id        date   region sales_channel customer_segment  \
# 429  ORD202392074  2024-04-15     West        Online        Corporate
# 30   ORD202456438  2024-03-09    North         Phone   Small Business
# 471  ORD202452762  2023-11-22    North        Online       Individual
# 478  ORD202328322  2023-05-05    South        Online       Individual
# 177  ORD202476039  2023-08-15  Central         Phone        Corporate
#
#         category         product  quantity  unit_price  total_sales  \
# 429  Electronics          Laptop        40      977.74     39109.60
# 30         Books          Comics        32       35.94      1150.08
# 471        Books     Educational        14       46.54       651.56
# 478  Electronics          Laptop        16      941.18     15058.88
# 177         Toys  Action Figures        38       87.42      3321.96
#
#      discount_percent  shipping_cost  profit_margin  discount_amount  \
# ...

# %%
online=df[df["sales_channel"]=="Online"]

# %%
online
# Out:
#          order_id        date   region sales_channel customer_segment  \
# 0    ORD202313278  2023-10-09    North        Online   Small Business
# 1    ORD202387397  2024-03-08    South        Online       Individual
# 4    ORD202354118  2023-04-15     East        Online        Corporate
# 7    ORD202316006  2024-11-08    South        Online       Individual
# 8    ORD202446434  2024-04-09     East        Online        Corporate
# ..            ...         ...      ...           ...              ...
# 492  ORD202484403  2024-07-31     West        Online   Small Business
# 493  ORD202433010  2024-05-17    South        Online   Small Business
# 495  ORD202354663  2023-07-01    North        Online       Individual
# 496  ORD202324538  2024-06-22     East        Online   Small Business
# 498  ORD202493789  2024-05-13  Central        Online   Small Business
#
#           category        product  quantity  unit_price  total_sales  \
# ...

# %%
online_jeans=online[online["product"]=="Jeans"]

# %%
online_jeans
# Out:
#          order_id        date   region sales_channel customer_segment  \
# 0    ORD202313278  2023-10-09    North        Online   Small Business
# 223  ORD202473736  2023-07-16    North        Online        Corporate
# 225  ORD202388282  2024-01-21  Central        Online       Individual
# 244  ORD202472722  2024-10-08     West        Online       Individual
# 356  ORD202310836  2024-02-27    South        Online       Individual
# 360  ORD202322624  2024-06-20  Central        Online   Small Business
#
#      category product  quantity  unit_price  total_sales  discount_percent  \
# 0    Clothing   Jeans        39      163.38      6371.82             19.49
# 223  Clothing   Jeans        39      129.87      5064.93              9.92
# 225  Clothing   Jeans        35      171.48      6001.80             23.88
# 244  Clothing   Jeans        49       92.35      4525.15             15.69
# 356  Clothing   Jeans        34       49.94      1697.96             13.08
# ...

# %% [markdown]
# df.to_csv('../Datasets/indian_college_cleaned_data.csv', index=False)

# %% [markdown]
# ### saprating data region wise

# %%
df["region"].unique()
# Out:
# array(['North', 'South', 'East', 'Central', 'West'], dtype=object)

# %%
East_data=df[df["region"]=="East"]

# %%
North_data=df[df["region"]=="North"]

# %%
South_data=df[df["region"]=="South"]

# %%
Central_data=df[df["region"]=="Central"]

# %%
West_data=df[df["region"]=="West"]

# %%
Dumbbells_data=east_data[east_data["product"]=="Dumbbells"]

# %%
Dumbbells_data["total_sales"].sum()
# Out:
# np.float64(20066.12)
