# %%
import pandas as pd

# %%
uber=pd.read_csv("csv data files/uber.csv")

# %%
uber.shape
# Out:
# (150000, 21)

# %%
uber["Date"]=uber['Date'].astype('datetime64[ns]')

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  datetime64[ns]
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        10500 non-null   float64
# ...

# %%
uber["Date"]=uber["Date"].astype("datetime64[ns]")

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  datetime64[ns]
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        10500 non-null   float64
# ...

# %%
from datetime import datetime

# %%
start=datetime.strptime("01-03-2024","%d-%m-%Y")
end=datetime.strptime("31-03-2024","%d-%m-%Y")

# %%
max_user=uber=uber[uber["Date"].between(start,end)]

# %%
max_user
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"      No Driver Found  "CID1982111"
# 7      2024-03-19  17:37:37  "CNR6568000"            Completed  "CID8610436"
# 23     2024-03-09  20:14:24  "CNR5309981"            Completed  "CID3870048"
# 54     2024-03-04  17:46:46  "CNR6092529"  Cancelled by Driver  "CID5040634"
# 63     2024-03-02  04:59:03  "CNR8946337"  Cancelled by Driver  "CID6438326"
# ...           ...       ...           ...                  ...           ...
# 149955 2024-03-24  09:45:35  "CNR3884070"            Completed  "CID3117846"
# 149977 2024-03-02  13:22:23  "CNR9330412"  Cancelled by Driver  "CID3815156"
# 149983 2024-03-23  20:33:36  "CNR1937316"            Completed  "CID7955264"
# 149986 2024-03-15  17:49:46  "CNR5247039"            Completed  "CID6218492"
# 149999 2024-03-10  15:38:03  "CNR3447390"            Completed  "CID4108667"
#
# ...

# %%
max_user
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"      No Driver Found  "CID1982111"
# 7      2024-03-19  17:37:37  "CNR6568000"            Completed  "CID8610436"
# 23     2024-03-09  20:14:24  "CNR5309981"            Completed  "CID3870048"
# 54     2024-03-04  17:46:46  "CNR6092529"  Cancelled by Driver  "CID5040634"
# 63     2024-03-02  04:59:03  "CNR8946337"  Cancelled by Driver  "CID6438326"
# ...           ...       ...           ...                  ...           ...
# 149955 2024-03-24  09:45:35  "CNR3884070"            Completed  "CID3117846"
# 149977 2024-03-02  13:22:23  "CNR9330412"  Cancelled by Driver  "CID3815156"
# 149983 2024-03-23  20:33:36  "CNR1937316"            Completed  "CID7955264"
# 149986 2024-03-15  17:49:46  "CNR5247039"            Completed  "CID6218492"
# 149999 2024-03-10  15:38:03  "CNR3447390"            Completed  "CID4108667"
#
# ...

# %%
max_user.shape
# Out:
# (12719, 21)

# %%
uber["Customer ID"].value_counts().unique
# Out:
# <bound method Series.unique of Customer ID
# "CID6994370"    2
# "CID7932933"    2
# "CID1317720"    2
# "CID7007776"    2
# "CID1008198"    2
#                ..
# "CID8247295"    1
# "CID9571923"    1
# "CID9377114"    1
# "CID4477763"    1
# "CID5040634"    1
# Name: count, Length: 12708, dtype: int64>

# %%
max_user
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"      No Driver Found  "CID1982111"
# 7      2024-03-19  17:37:37  "CNR6568000"            Completed  "CID8610436"
# 23     2024-03-09  20:14:24  "CNR5309981"            Completed  "CID3870048"
# 54     2024-03-04  17:46:46  "CNR6092529"  Cancelled by Driver  "CID5040634"
# 63     2024-03-02  04:59:03  "CNR8946337"  Cancelled by Driver  "CID6438326"
# ...           ...       ...           ...                  ...           ...
# 149955 2024-03-24  09:45:35  "CNR3884070"            Completed  "CID3117846"
# 149977 2024-03-02  13:22:23  "CNR9330412"  Cancelled by Driver  "CID3815156"
# 149983 2024-03-23  20:33:36  "CNR1937316"            Completed  "CID7955264"
# 149986 2024-03-15  17:49:46  "CNR5247039"            Completed  "CID6218492"
# 149999 2024-03-10  15:38:03  "CNR3447390"            Completed  "CID4108667"
#
# ...

# %%
max_user[max_user]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6512\2248350355.py in ?()
# ----> 1 max_user[max_user]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py in ?(self, key)
#    4096             return self._getitem_slice(key)
#    4097
#    4098         # Do we have a (boolean) DataFrame?
#    4099         if isinstance(key, DataFrame):
# -> 4100             return self.where(key)
#    4101
#    4102         # Do we have a (boolean) 1d indexer?
#    4103         if com.is_bool_indexer(key):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   11044                         stacklevel=2,
# ...

# %%
uber
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"      No Driver Found  "CID1982111"
# 7      2024-03-19  17:37:37  "CNR6568000"            Completed  "CID8610436"
# 23     2024-03-09  20:14:24  "CNR5309981"            Completed  "CID3870048"
# 54     2024-03-04  17:46:46  "CNR6092529"  Cancelled by Driver  "CID5040634"
# 63     2024-03-02  04:59:03  "CNR8946337"  Cancelled by Driver  "CID6438326"
# ...           ...       ...           ...                  ...           ...
# 149955 2024-03-24  09:45:35  "CNR3884070"            Completed  "CID3117846"
# 149977 2024-03-02  13:22:23  "CNR9330412"  Cancelled by Driver  "CID3815156"
# 149983 2024-03-23  20:33:36  "CNR1937316"            Completed  "CID7955264"
# 149986 2024-03-15  17:49:46  "CNR5247039"            Completed  "CID6218492"
# 149999 2024-03-10  15:38:03  "CNR3447390"            Completed  "CID4108667"
#
# ...

# %%
uber.shape
# Out:
# (12719, 21)

# %%
uber.sample(5)
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 139543 2024-03-29  20:32:34  "CNR6183298"      No Driver Found  "CID3299099"
# 33871  2024-03-15  09:38:18  "CNR1966535"            Completed  "CID9827250"
# 22376  2024-03-22  15:48:11  "CNR3475078"            Completed  "CID8751233"
# 28689  2024-03-16  15:37:19  "CNR9462788"            Completed  "CID9870786"
# 104839 2024-03-01  15:15:29  "CNR4487539"  Cancelled by Driver  "CID2331290"
#
#          Vehicle Type  Pickup Location     Drop Location  Avg VTAT  Avg CTAT  \
# 139543           Auto        Lal Quila       Laxmi Nagar       NaN       NaN
# 33871            Auto      DLF Phase 3      Chanakyapuri      14.8      43.9
# 22376   Premier Sedan         Mehrauli         Arjangarh       8.6      32.0
# 28689        Go Sedan  Noida Sector 62      Nirman Vihar       8.2      23.0
# 104839           Bike            Saket  Dwarka Sector 21      11.4       NaN
#
# ...

# %%
uber.drop(["Incomplete Rides Reason","Cancelled Rides by Driver","Driver Ratings","Avg VTAT","Avg CTAT","Reason for cancelling by Customer"],axis=1)
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"      No Driver Found  "CID1982111"
# 7      2024-03-19  17:37:37  "CNR6568000"            Completed  "CID8610436"
# 23     2024-03-09  20:14:24  "CNR5309981"            Completed  "CID3870048"
# 54     2024-03-04  17:46:46  "CNR6092529"  Cancelled by Driver  "CID5040634"
# 63     2024-03-02  04:59:03  "CNR8946337"  Cancelled by Driver  "CID6438326"
# ...           ...       ...           ...                  ...           ...
# 149955 2024-03-24  09:45:35  "CNR3884070"            Completed  "CID3117846"
# 149977 2024-03-02  13:22:23  "CNR9330412"  Cancelled by Driver  "CID3815156"
# 149983 2024-03-23  20:33:36  "CNR1937316"            Completed  "CID7955264"
# 149986 2024-03-15  17:49:46  "CNR5247039"            Completed  "CID6218492"
# 149999 2024-03-10  15:38:03  "CNR3447390"            Completed  "CID4108667"
#
# ...

# %%
uber=uber.rename(columns={"Vehicle Type":"gadi"})

# %%
uber
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"      No Driver Found  "CID1982111"
# 7      2024-03-19  17:37:37  "CNR6568000"            Completed  "CID8610436"
# 23     2024-03-09  20:14:24  "CNR5309981"            Completed  "CID3870048"
# 54     2024-03-04  17:46:46  "CNR6092529"  Cancelled by Driver  "CID5040634"
# 63     2024-03-02  04:59:03  "CNR8946337"  Cancelled by Driver  "CID6438326"
# ...           ...       ...           ...                  ...           ...
# 149955 2024-03-24  09:45:35  "CNR3884070"            Completed  "CID3117846"
# 149977 2024-03-02  13:22:23  "CNR9330412"  Cancelled by Driver  "CID3815156"
# 149983 2024-03-23  20:33:36  "CNR1937316"            Completed  "CID7955264"
# 149986 2024-03-15  17:49:46  "CNR5247039"            Completed  "CID6218492"
# 149999 2024-03-10  15:38:03  "CNR3447390"            Completed  "CID4108667"
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 uber["Customer Rating"].astype("int")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# ...

# %%
uber.sort_values(["Customer ID"], ascending=True)
# Out:
#              Date      Time    Booking ID         Booking Status  \
# 79865  2024-03-18  20:39:24  "CNR1636134"             Incomplete
# 43914  2024-03-22  10:10:36  "CNR1145949"              Completed
# 147050 2024-03-02  11:44:26  "CNR8380864"              Completed
# 85810  2024-03-12  09:44:37  "CNR7173992"  Cancelled by Customer
# 87589  2024-03-03  09:39:48  "CNR1919535"             Incomplete
# ...           ...       ...           ...                    ...
# 62165  2024-03-05  15:35:39  "CNR2993714"              Completed
# 131300 2024-03-21  20:34:17  "CNR7121663"             Incomplete
# 61770  2024-03-16  17:09:01  "CNR6138134"              Completed
# 50524  2024-03-11  16:24:49  "CNR4708579"              Completed
# 80022  2024-03-02  19:35:47  "CNR1938007"              Completed
#
#          Customer ID           gadi      Pickup Location      Drop Location  \
# 79865   "CID1000119"           Bike  Raj Nagar Extension          Kaushambi
# ...

# %%
uber
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"      No Driver Found  "CID1982111"
# 7      2024-03-19  17:37:37  "CNR6568000"            Completed  "CID8610436"
# 23     2024-03-09  20:14:24  "CNR5309981"            Completed  "CID3870048"
# 54     2024-03-04  17:46:46  "CNR6092529"  Cancelled by Driver  "CID5040634"
# 63     2024-03-02  04:59:03  "CNR8946337"  Cancelled by Driver  "CID6438326"
# ...           ...       ...           ...                  ...           ...
# 149955 2024-03-24  09:45:35  "CNR3884070"            Completed  "CID3117846"
# 149977 2024-03-02  13:22:23  "CNR9330412"  Cancelled by Driver  "CID3815156"
# 149983 2024-03-23  20:33:36  "CNR1937316"            Completed  "CID7955264"
# 149986 2024-03-15  17:49:46  "CNR5247039"            Completed  "CID6218492"
# 149999 2024-03-10  15:38:03  "CNR3447390"            Completed  "CID4108667"
#
# ...

# %%
uber["Reason for cancelling by Customer"].unique()
# Out:
# array([nan, 'AC is not working', 'Change of plans',
#        'Driver is not moving towards pickup location',
#        'Driver asked to cancel', 'Wrong Address'], dtype=object)

# %%
uber.fillna({"Reason for cancelling by Customer": "man nhi tha jane ka  "} ,inplace=True)

# %%
uber
# Out:
#              Date      Time    Booking ID       Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"      No Driver Found  "CID1982111"
# 7      2024-03-19  17:37:37  "CNR6568000"            Completed  "CID8610436"
# 23     2024-03-09  20:14:24  "CNR5309981"            Completed  "CID3870048"
# 54     2024-03-04  17:46:46  "CNR6092529"  Cancelled by Driver  "CID5040634"
# 63     2024-03-02  04:59:03  "CNR8946337"  Cancelled by Driver  "CID6438326"
# ...           ...       ...           ...                  ...           ...
# 149955 2024-03-24  09:45:35  "CNR3884070"            Completed  "CID3117846"
# 149977 2024-03-02  13:22:23  "CNR9330412"  Cancelled by Driver  "CID3815156"
# 149983 2024-03-23  20:33:36  "CNR1937316"            Completed  "CID7955264"
# 149986 2024-03-15  17:49:46  "CNR5247039"            Completed  "CID6218492"
# 149999 2024-03-10  15:38:03  "CNR3447390"            Completed  "CID4108667"
#
# ...
