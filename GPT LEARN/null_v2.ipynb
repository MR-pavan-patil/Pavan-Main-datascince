# %% [markdown]
# # Advanced Pandas Null Values Handling Practice
#
# This notebook contains comprehensive practice questions for mastering null value handling in pandas.
#
# **Dataset:** sales_data.csv (50 employee records with strategic missing values)
#
# **Skills Covered:**
# - Detection and visualization of missing data
# - Dropping strategies
# - Filling techniques (mean, median, mode, forward/backward fill, interpolation)
# - Conditional and group-based imputation
# - Advanced cleaning pipelines

# %% [markdown]
# ## Setup: Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Load the dataset
df = pd.read_csv('csv data files/null_v2.csv')
print("Dataset loaded successfully!")
print(f"Shape: {df.shape}")
df.head(10)
# Out:
# Dataset loaded successfully!
# Shape: (50, 15)
#    employee_id            name department   salary   age  sales_amount  \
# 0          101      John Smith      Sales  55000.0  28.0       12500.0
# 1          102    Maria Garcia        NaN  62000.0  34.0       15800.0
# 2          103    James Wilson  Marketing  48000.0   NaN       11200.0
# 3          104   Lisa Anderson      Sales      NaN  29.0       14500.0
# 4          105    Robert Brown         IT  75000.0  42.0           NaN
# 5          106             NaN  Marketing  51000.0  31.0        9800.0
# 6          107     Emily Davis      Sales  58000.0  27.0       16200.0
# 7          108     Michael Lee        NaN  69000.0  38.0           NaN
# 8          109    Sarah Taylor         IT      NaN  33.0       13400.0
# 9          110  David Martinez  Marketing  54000.0   NaN           NaN
#
#     join_date  performance_score  years_experience   bonus  \
# 0  2020-03-15                8.5               3.0  5500.0
# ...

# %% [markdown]
# ---
# ## Section 1: Basic Detection and Exploration
# ---

# %% [markdown]
# ### Question 1: Comprehensive Null Analysis
#
# **Task:**
# - Display the total count of null values in each column
# - Calculate and display the percentage of null values for each column
# - Identify which column has the highest percentage of missing data
# - Create a bar chart showing null percentages for all columns

# %%
# Your code here
sum_data=df.isnull().sum()
max_data=df.isnull().sum() /len(df)*100
max_sum=sum_data.max()
sum_data[sum_data== max_sum]
# Out:
# sales_amount    15
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   employee_id        50 non-null     int64
#  1   name               44 non-null     object
#  2   department         38 non-null     object
#  3   salary             40 non-null     float64
#  4   age                41 non-null     float64
#  5   sales_amount       35 non-null     float64
#  6   join_date          42 non-null     object
#  7   performance_score  37 non-null     float64
#  8   years_experience   44 non-null     float64
#  9   bonus              40 non-null     float64
#  10  email              36 non-null     object
#  11  phone              41 non-null     object
#  12  city               44 non-null     object
#  13  country            38 non-null     object
#  14  project_count      39 non-null     float64
# dtypes: float64(7), int64(1), object(7)
# ...

# %% [markdown]
# ### Question 2: Missing Data Patterns
#
# **Task:**
# - Find how many rows have exactly 1 missing value
# - Find how many rows have 2 or more missing values
# - Find how many rows have no missing values
# - Display the 5 rows with the most missing values

# %%
# Your code here
df.isnull()

# %% [markdown]
# ### Question 3: Heatmap Visualization
#
# **Task:**
# - Create a heatmap using seaborn to visualize missing data patterns
# - Use a color scheme where missing values are clearly highlighted
# - What patterns do you notice?

# %%
# Your code here
# Hint: Use sns.heatmap() with df.isnull()

# %% [markdown]
# ---
# ## Section 2: Dropping Strategies
# ---

# %% [markdown]
# ### Question 4: Smart Row Dropping
#
# **Task:**
# - Create a copy of the dataframe
# - Drop rows where 'employee_id' or 'name' is missing (these are critical fields)
# - How many rows were dropped?
# - What percentage of the original data remains?

# %%
# Your code here

# %% [markdown]
# ### Question 5: Threshold-Based Dropping
#
# **Task:**
# - Drop rows that have more than 5 missing values
# - Drop columns that have more than 30% missing values
# - Show the shape before and after these operations

# %%
# Your code here

# %% [markdown]
# ### Question 6: Subset Dropping
#
# **Task:**
# - Drop rows that have missing values in ALL of these columns: ['salary', 'age', 'sales_amount']
# - Drop rows that have missing values in ANY of these columns: ['email', 'phone']
# - Compare the results

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 3: Simple Filling Methods
# ---

# %% [markdown]
# ### Question 7: Statistical Filling
#
# **Task:**
# - Fill null values in 'salary' with the mean salary
# - Fill null values in 'age' with the median age
# - Fill null values in 'performance_score' with the median score
# - Display summary statistics before and after filling

# %%
# Your code here

# %% [markdown]
# ### Question 8: Categorical Filling
#
# **Task:**
# - Fill null values in 'department' with the mode (most frequent department)
# - Fill null values in 'name' with 'Anonymous Employee'
# - Fill null values in 'city' with 'Unknown City'
# - Fill null values in 'country' with 'USA'
# - Verify these columns have no nulls remaining

# %%
# Your code here

# %% [markdown]
# ### Question 9: Fill with Constant Values
#
# **Task:**
# - For 'sales_amount', fill missing values with 0 (assuming no sales if not recorded)
# - For 'bonus', fill missing values with 0
# - For 'project_count', fill missing values with 0
# - Calculate the total sales_amount before and after filling

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 4: Advanced Filling Techniques
# ---

# %% [markdown]
# ### Question 10: Group-Based Filling
#
# **Task:**
# - Fill missing 'salary' values with the mean salary of their respective department
# - Fill missing 'performance_score' with the mean score of their respective department
# - Display the mean salary and performance score by department before and after filling

# %%
# Your code here
# Hint: Use groupby() and transform()

# %% [markdown]
# ### Question 11: Conditional Filling Based on Multiple Conditions
#
# **Task:**
# - Fill missing 'years_experience' based on age:
#   - If age < 25: fill with 1
#   - If age 25-35: fill with 5
#   - If age > 35: fill with 10
# - Verify the filling logic worked correctly

# %%
# Your code here
# Hint: Use np.where() or multiple conditions

# %% [markdown]
# ### Question 12: Forward Fill and Backward Fill
#
# **Task:**
# - Sort the DataFrame by 'join_date'
# - Use forward fill on 'performance_score' to propagate last known score forward
# - Use backward fill for any remaining nulls
# - How many nulls remain after this operation?

# %%
# Your code here

# %% [markdown]
# ### Question 13: Interpolation Methods
#
# **Task:**
# - Sort by 'employee_id'
# - Use linear interpolation to fill missing values in 'salary'
# - Use polynomial interpolation (order=2) to fill missing 'age' values
# - Compare results with mean filling - which preserves data distribution better?

# %%
# Your code here
# Hint: Use df.interpolate(method='linear') and method='polynomial'

# %% [markdown]
# ### Question 14: Creating Derived Values
#
# **Task:**
# - For missing 'bonus' values, calculate them as 12% of salary
# - For missing 'email' values, create them from name: firstname.lastname@company.com (lowercase)
# - Handle cases where name might also be missing

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 5: Detection of Data Quality Issues
# ---

# %% [markdown]
# ### Question 15: Finding Implicit Missing Values
#
# **Task:**
# - Check if there are any empty strings ('') in string columns
# - Check if there are any 'Unknown', 'N/A', 'None' text values that should be treated as null
# - Replace these with actual NaN values
# - How many additional missing values did you find?

# %%
# Your code here

# %% [markdown]
# ### Question 16: Detecting Outliers That Might Indicate Errors
#
# **Task:**
# - Find any salary values that are more than 3 standard deviations from the mean
# - Find any age values that are unrealistic (e.g., < 18 or > 70)
# - Find any negative values in numeric columns
# - Consider replacing these with NaN for proper handling

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 6: Advanced Analysis
# ---

# %% [markdown]
# ### Question 17: Correlation Analysis of Missing Data
#
# **Task:**
# - Create a correlation matrix showing relationships between missing values across columns
# - Are there patterns? (e.g., when salary is missing, is age also often missing?)
# - Visualize this correlation with a heatmap

# %%
# Your code here
# Hint: Create a boolean DataFrame of nulls, then calculate correlation

# %% [markdown]
# ### Question 18: Impact Analysis
#
# **Task:**
# - Calculate average salary for:
#   - Rows with complete data
#   - Rows with at least one missing value
# - Is there a significant difference? What might this indicate?
# - Repeat this analysis for performance_score

# %%
# Your code here

# %% [markdown]
# ### Question 19: Department-wise Missing Data Analysis
#
# **Task:**
# - Group by department and show:
#   - Total missing values per department
#   - Percentage of missing values per department
#   - Which department has the most complete data?
# - Create a grouped bar chart showing this analysis

# %%
# Your code here

# %% [markdown]
# ### Question 20: Time-Based Analysis
#
# **Task:**
# - Convert 'join_date' to datetime
# - Extract the year from join_date
# - Analyze if newer employees (joined more recently) have more or less missing data
# - Create a visualization showing missing data trend over time

# %%
# Your code here

# %% [markdown]
# ---
# ## Section 7: Complete Cleaning Pipeline
# ---

# %% [markdown]
# ### Question 21: Build a Comprehensive Cleaning Function
#
# **Task:**
# Create a function `clean_employee_data(df)` that:
# 1. Handles implicit missing values (empty strings, 'Unknown', etc.)
# 2. Drops rows where critical fields (employee_id, name) are missing
# 3. Fills numeric columns appropriately (mean, median, or group-based)
# 4. Fills categorical columns appropriately (mode or specific values)
# 5. Handles date columns
# 6. Creates a summary report of all changes made
# 7. Returns the cleaned DataFrame
#
# Test your function on the original data!

# %%
# Your code here
def clean_employee_data(df):
    """
    Comprehensive cleaning pipeline for employee data
    
    Parameters:
    df (DataFrame): Raw employee data
    
    Returns:
    DataFrame: Cleaned employee data
    """
    # Your cleaning logic here
    pass

# Test your function
# df_clean = clean_employee_data(df.copy())

# %% [markdown]
# ### Question 22: Comparison of Strategies
#
# **Task:**
# Compare three different approaches:
# 1. Aggressive dropping (drop any row with missing values)
# 2. Simple mean/median filling
# 3. Your sophisticated cleaning pipeline from Q21
#
# For each approach, calculate:
# - Number of rows retained
# - Mean salary
# - Mean performance score
# - Standard deviation of salary
#
# Which approach preserves the data best while maintaining quality?

# %%
# Your code here

# %% [markdown]
# ### Question 23: Validation and Quality Checks
#
# **Task:**
# After cleaning, perform these validation checks:
# 1. Verify no nulls remain (or document acceptable nulls)
# 2. Check for duplicate employee_ids
# 3. Verify salary values are in reasonable range
# 4. Verify age values are realistic (18-70)
# 5. Check that email format is valid (contains @)
# 6. Verify performance_score is between 0-10
#
# Create a validation report showing pass/fail for each check

# %%
# Your code here

# %% [markdown]
# ### Question 24: Export Clean Data
#
# **Task:**
# - Save your cleaned DataFrame to 'sales_data_cleaned.csv'
# - Create a separate 'cleaning_report.txt' file documenting:
#   - Original dataset shape
#   - Final dataset shape
#   - Number of nulls handled per column
#   - Strategies used for each column
#   - Any data quality issues found and resolved

# %%
# Your code here

# %% [markdown]
# ---
# ## Bonus Challenges
# ---

# %% [markdown]
# ### Bonus 1: Multiple Imputation Simulation
#
# **Task:**
# - Create 3 different versions of the cleaned data using different imputation strategies
# - Calculate the variance in key metrics (mean salary, mean performance) across versions
# - Discuss the uncertainty introduced by different imputation methods

# %%
# Your code here

# %% [markdown]
# ### Bonus 2: Custom Imputation Based on ML
#
# **Task:**
# - Use KNN imputation or another ML-based method to fill missing salary values
# - Compare results with simple mean filling
# - Which method produces more realistic values?

# %%
# Your code here
# Hint: You may need to install scikit-learn: from sklearn.impute import KNNImputer

# %% [markdown]
# ### Bonus 3: Missing Data Mechanism Analysis
#
# **Task:**
# Research and identify whether missing data in this dataset is:
# - MCAR (Missing Completely At Random)
# - MAR (Missing At Random)
# - MNAR (Missing Not At Random)
#
# Provide evidence for your conclusion and discuss implications for your imputation strategy

# %%
# Your analysis here

# %% [markdown]
# ### Bonus 4: Create Your Own Missing Data
#
# **Task:**
# - Load a complete dataset (create one or use an existing one)
# - Artificially introduce missing values with specific patterns
# - Challenge yourself to recover the original values using imputation
# - Calculate accuracy of your imputation methods

# %%
# Your code here

# %% [markdown]
# ---
# ## Summary and Reflection
#
# Write your learnings below:
#
# 1. **Most effective technique for this dataset:**
#
# 2. **Biggest challenge faced:**
#
# 3. **Key takeaways:**
#
# 4. **When to drop vs. fill:**
#
# 5. **Real-world applications:**
#
# ---
#
# **Congratulations on completing this comprehensive null handling practice! 🎉**
