# %%
import pandas as pd

# %%
df=pd.read_csv("csv data files/pavan-sales.csv")

# %%
df.sample(5)
# Out:
#     Order_ID        Date Customer_ID Customer_Name  Age Gender  \
# 20    ORD021  2024-01-23    CUST1020  Rohit Sharma   31   Male
# 59    ORD060  2024-03-02    CUST1054  Rajeev Kumar   42   Male
# 46    ORD047  2024-02-18    CUST1043   Aditya Nair   27   Male
# 196   ORD197  2024-07-17    CUST1184   Umesh Patel   36   Male
# 47    ORD048  2024-02-19    CUST1012  Manoj Tiwari   41   Male
#
#                    City           State   Region Product_ID  ... Quantity  \
# 20                Delhi           Delhi    North    PROD311  ...        1
# 59              Gwalior  Madhya Pradesh  Central    PROD115  ...        1
# 46   Thiruvananthapuram          Kerala    South    PROD112  ...        1
# 196         Banaskantha         Gujarat     West    PROD138  ...        3
# 47                Patna           Bihar     East    PROD435  ...        1
#
#     Unit_Price Discount_Percent Shipping_Cost  Total_Amount  Payment_Method  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          200 non-null    object
#  1   Date              200 non-null    object
#  2   Customer_ID       200 non-null    object
#  3   Customer_Name     200 non-null    object
#  4   Age               200 non-null    int64
#  5   Gender            200 non-null    object
#  6   City              200 non-null    object
#  7   State             200 non-null    object
#  8   Region            200 non-null    object
#  9   Product_ID        200 non-null    object
#  10  Product_Name      200 non-null    object
#  11  Category          200 non-null    object
#  12  Sub_Category      200 non-null    object
#  13  Brand             200 non-null    object
#  14  Quantity          200 non-null    int64
#  15  Unit_Price        200 non-null    int64
# ...

# %%
df["Customer_ID"].unique()
# Out:
# array(['CUST1001', 'CUST1002', 'CUST1003', 'CUST1004', 'CUST1005',
#        'CUST1006', 'CUST1007', 'CUST1008', 'CUST1009', 'CUST1010',
#        'CUST1011', 'CUST1012', 'CUST1013', 'CUST1014', 'CUST1015',
#        'CUST1016', 'CUST1017', 'CUST1018', 'CUST1019', 'CUST1020',
#        'CUST1021', 'CUST1022', 'CUST1023', 'CUST1024', 'CUST1025',
#        'CUST1026', 'CUST1027', 'CUST1028', 'CUST1029', 'CUST1030',
#        'CUST1031', 'CUST1032', 'CUST1033', 'CUST1034', 'CUST1035',
#        'CUST1036', 'CUST1037', 'CUST1038', 'CUST1039', 'CUST1040',
#        'CUST1041', 'CUST1042', 'CUST1043', 'CUST1044', 'CUST1045',
#        'CUST1046', 'CUST1047', 'CUST1048', 'CUST1049', 'CUST1050',
#        'CUST1051', 'CUST1052', 'CUST1053', 'CUST1054', 'CUST1055',
#        'CUST1056', 'CUST1057', 'CUST1058', 'CUST1059', 'CUST1060',
#        'CUST1061', 'CUST1062', 'CUST1063', 'CUST1064', 'CUST1065',
#        'CUST1066', 'CUST1067', 'CUST1068', 'CUST1069', 'CUST1070',
# ...

# %%
df["Customer_ID"].value_counts()
# Out:
# Customer_ID
# CUST1001    2
# CUST1002    2
# CUST1003    2
# CUST1005    2
# CUST1007    2
#            ..
# CUST1183    1
# CUST1184    1
# CUST1185    1
# CUST1186    1
# CUST1187    1
# Name: count, Length: 187, dtype: int64

# %%
df
# Out:
#     Order_ID        Date Customer_ID   Customer_Name  Age  Gender  \
# 0     ORD001  2024-01-05    CUST1001    Rajesh Kumar   34    Male
# 1     ORD002  2024-01-05    CUST1002    Priya Sharma   28  Female
# 2     ORD003  2024-01-06    CUST1003      Amit Patel   42    Male
# 3     ORD004  2024-01-07    CUST1004     Sneha Reddy   31  Female
# 4     ORD005  2024-01-08    CUST1005    Vikram Singh   45    Male
# ..       ...         ...         ...             ...  ...     ...
# 195   ORD196  2024-07-16    CUST1183   Garima Sharma   28  Female
# 196   ORD197  2024-07-17    CUST1184     Umesh Patel   36    Male
# 197   ORD198  2024-07-18    CUST1185      Vidya Nair   29  Female
# 198   ORD199  2024-07-19    CUST1186  Akhilesh Singh   33    Male
# 199   ORD200  2024-07-20    CUST1187    Geetha Reddy   31  Female
#
#              City           State Region Product_ID  ... Quantity Unit_Price  \
# 0          Mumbai     Maharashtra   West    PROD101  ...        1      45000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          200 non-null    object
#  1   Date              200 non-null    object
#  2   Customer_ID       200 non-null    object
#  3   Customer_Name     200 non-null    object
#  4   Age               200 non-null    int64
#  5   Gender            200 non-null    object
#  6   City              200 non-null    object
#  7   State             200 non-null    object
#  8   Region            200 non-null    object
#  9   Product_ID        200 non-null    object
#  10  Product_Name      200 non-null    object
#  11  Category          200 non-null    object
#  12  Sub_Category      200 non-null    object
#  13  Brand             200 non-null    object
#  14  Quantity          200 non-null    int64
#  15  Unit_Price        200 non-null    int64
# ...

# %%
from datetime import datetime

# %%
def date_time(x):
    tarikha=datetime.strptime(x,"%Y-%m-%d") 
    return tarikha
    tarikha=date_time("%A")

# %%
df["Date"].apply(date_time)
# Out:
# 0     2024-01-05
# 1     2024-01-05
# 2     2024-01-06
# 3     2024-01-07
# 4     2024-01-08
#          ...
# 195   2024-07-16
# 196   2024-07-17
# 197   2024-07-18
# 198   2024-07-19
# 199   2024-07-20
# Name: Date, Length: 200, dtype: datetime64[ns]

# %%
#   tarikha=date_time.strptime(x,"%A")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 tarikha=date_time.strptime(x,"%A")
#
# AttributeError: 'function' object has no attribute 'strptime'
