# %% [markdown]
# ###  college dataset

# %% [markdown]
# #### importing pandas lab

# %%
import pandas as pd

# %% [markdown]
# #### importing csv dataset  file  (pavan-college.csv)

# %%
df= pd.read_csv("csv data files/pavan-college.csv")

# %%
df.sample(5)
# Out:
#    College_ID       College_Name        City      State        Type  \
# 1        C002          IIT Delhi   New Delhi      Delhi  Government
# 14       C015          BIT Mesra      Ranchi  Jharkhand     Private
# 33       C034  Panjab University  Chandigarh     Punjab  Government
# 6        C007        BITS Pilani      Pilani  Rajasthan     Private
# 30       C031       NIT Warangal    Warangal  Telangana  Government
#
#     Established_Year  Total_Students  NIRF_Rank  Average_Package_LPA  \
# 1               1961           11200          2                 17.8
# 14              1955           12500         30                  6.5
# 33              1882           18500         64                  4.5
# 6               1964           18500         25                  9.8
# 30              1959            7800         21                  9.2
#
#     Highest_Package_LPA  Placement_Rate  Faculty_Count  Student_Faculty_Ratio  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   College_ID             40 non-null     object
#  1   College_Name           40 non-null     object
#  2   City                   40 non-null     object
#  3   State                  40 non-null     object
#  4   Type                   40 non-null     object
#  5   Established_Year       40 non-null     int64
#  6   Total_Students         40 non-null     int64
#  7   NIRF_Rank              40 non-null     int64
#  8   Average_Package_LPA    40 non-null     float64
#  9   Highest_Package_LPA    40 non-null     float64
#  10  Placement_Rate         40 non-null     float64
#  11  Faculty_Count          40 non-null     int64
#  12  Student_Faculty_Ratio  40 non-null     int64
#  13  Campus_Size_Acres      40 non-null     int64
# ...
