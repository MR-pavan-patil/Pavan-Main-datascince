# %% [markdown]
# ## ✅ Handling Null Values in Pandas — Full Detailed Notes
#
# ##### In data science, null values (missing data) are very common. Pandas provides many powerful functions to identify, clean, replace, and handle missing values.

# %% [markdown]
# ## ⭐ 1. Types of Missing Values in Pandas
#
# ### In pandas, missing data can appear as:
#
#
#
# ##### Type	Meaning
# ##### NaN	Not a Number (float missing value)
# ##### None	Python’s None (object missing value)
#  ##### NaT	Not a Time (datetime missing value)

# %% [markdown]
# ### 2. Check Null Values
# ##### ✔ 2.1 isnull()
#
# Returns True where value is null.

# %%
import pandas as pd

# %%
df= pd.read_csv("csv data files/indian_college_messy_data.csv")

# %%
df
# Out:
#       student_id            name                        email  \
# 0    STU20238485     Yug Sanghvi    urvichauhan@example.net
# 1    STU20206913  PATRICK PRASAD        krishhora@example.com
# 2    STU20237737     teerth mody      shethvinaya@example.org
# 3    STU20212477       TRIYA BIR     kiberaksha@example.org
# 4    STU20221620    Chasmum Rana                          NaN
# ..           ...             ...                          ...
# 505  STU20243430  jacob merchant        timothy32@example.com
# 506  STU20241752   Atharv Parmer        soodkrish@example.net
# 507  STU20228414   Vritti Thaman        hemal88@example.org
# 508  STU20206410     Anjali Dube          lparmar@example.org
# 509  STU20223417     ABDUL DUGAR                          NaN
#
#                  phone  age      gender  course              department  \
# 0       +91-8923923126   17        Male     BCA  Information Technology
# 1      (+918179323023)   25  Non-Binary     M.E                Chemical
# ...

# %%
df[df["phone"].isnull()
# Out:
#       student_id                 name                           email phone  \
# 3    STU20212477            TRIYA BIR        kiberaksha@example.org     NaN
# 16   STU20227704        Yahvi Sampath           CHATURA15@EXAMPLE.COM   NaN
# 30   STU20239210     HARSHIL SANKARAN             vtandon@example.net   NaN
# 42   STU20215853        Pratyush Dhar              jboase@example.net   NaN
# 63   STU20231053           ARYA SHERE         faqidsavant@example.net   NaN
# 69   STU20204750        GIRINDRA RAJU          zayyan92@example.com     NaN
# 80   STU20238715        Vedhika Golla            ozafrado@example.org   NaN
# 82   STU20219370   gautam ranganathan   warinderchoudhury@example.net   NaN
# 85   STU20247981        Yachana Sagar              FRATTI@EXAMPLE.NET   NaN
# 99   STU20247221         Caleb Bhatti           advaith11@example.net   NaN
# 111  STU20206153          Triya Manda            HTHAKKAR@EXAMPLE.COM   NaN
# ...
