# %% [markdown]
# ####  indian_college_messy_data data cleaning

# %%
import pandas as pd

# %%
df=pd.read_csv("csv data files/indian_college_messy_data.csv")

# %%
df.sample(10)
# Out:
#       student_id            name                        email  \
# 126  STU20226901  RADHA RAGHAVAN      kotafaras@example.com
# 1    STU20206913  PATRICK PRASAD        krishhora@example.com
# 73   STU20204641      zinal tank            ngole@example.org
# 375  STU20206642      hemang ram                          NaN
# 122  STU20215516       neha keer    sharafsachi@example.net
# 450  STU20214062         Urvi Om       YASHASVI21@EXAMPLE.COM
# 463  STU20213419    Bakhshi Chad     toorchanchal@example.com
# 215  STU20226340     Darpan Kale       VAMAKSHI17@EXAMPLE.NET
# 451  STU20236038     PAHAL MENON   VARUGHESELUCKY@EXAMPLE.COM
# 472  STU20249947    Gautam Saraf    chaudhrysachi@example.org
#
#                phone  age      gender  course        department  semester  \
# 126    +918186151554   18        Male     B.E          Chemical         7
# 1    (+918179323023)   25  Non-Binary     M.E          Chemical         6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      510 non-null    object
#  1   name            510 non-null    object
#  2   email           466 non-null    object
#  3   phone           460 non-null    object
#  4   age             510 non-null    int64
#  5   gender          510 non-null    object
#  6   course          510 non-null    object
#  7   department      510 non-null    object
#  8   semester        510 non-null    int64
#  9   cgpa            480 non-null    float64
#  10  attendance      468 non-null    object
#  11  city            473 non-null    object
#  12  state           510 non-null    object
#  13  admission_date  510 non-null    object
#  14  fees_paid       510 non-null    object
#  15  hostel          510 non-null    object
# dtypes: float64(1), int64(2), object(13)
# ...

# %% [markdown]
# ## cleaning the hostel column

# %%
df["hostel"].unique()
# Out:
# array(['Yes', ' Yes ', 'YES', 'NO', 'n', 'N', 'yes', 'Y', 'no', 'No', 'y',
#        ' No '], dtype=object)

# %%
df["hostel"]=df["hostel"].apply(lambda x: x.upper())

# %%
df["hostel"].unique()
# Out:
# array(['YES', ' YES ', 'NO', 'N', 'Y', ' NO '], dtype=object)

# %%
def hostel_clean(x):
    if x == "N":
        x=x.replace("N","NO")
        return x
    else:
        x= "Yes"
        return x

# %%
df["hostel"]=df["hostel"].apply(hostel_clean)

# %%
df["hostel"].unique()
# Out:
# array(['Yes', 'NO'], dtype=object)

# %%
df.sample(5)
# Out:
#       student_id            name                         email  \
# 57   STU20238736      Ira Khosla                           NaN
# 437  STU20206077  VIVAAN IYENGAR        nachiket11@example.net
# 429  STU20205979       Ojas Buch                           NaN
# 184  STU20237184        Ayush De             HSURA@EXAMPLE.COM
# 279  STU20212016    pahal bansal  NATHANIELMAHAJAN@EXAMPLE.ORG
#
#                  phone  age  gender  course        department  semester  cgpa  \
# 57   +91-+918518888806   70   Woman     BCA       Electronics         7  5.95
# 437  +91-+913924051477   18   Other  M.Tech          Chemical         3  7.68
# 429  +91-+915093771004   68    MALE     BCA  Computer Science         2  8.63
# 184      (00145089935)   23    Male     MCA        Electrical         3  8.27
# 279                NaN   28  female  M.Tech          Chemical         1  6.79
#
#     attendance      city       state admission_date fees_paid hostel
# ...

# %% [markdown]
# ### cleaning name

# %%
df["name"]=df["name"].apply(lambda x: x.title())

# %%
df
# Out:
#       student_id            name                        email  \
# 0    STU20238485     Yug Sanghvi    urvichauhan@example.net
# 1    STU20206913  Patrick Prasad        krishhora@example.com
# 2    STU20237737     Teerth Mody      shethvinaya@example.org
# 3    STU20212477       Triya Bir     kiberaksha@example.org
# 4    STU20221620    Chasmum Rana                          NaN
# ..           ...             ...                          ...
# 505  STU20243430  Jacob Merchant        timothy32@example.com
# 506  STU20241752   Atharv Parmer        soodkrish@example.net
# 507  STU20228414   Vritti Thaman        hemal88@example.org
# 508  STU20206410     Anjali Dube          lparmar@example.org
# 509  STU20223417     Abdul Dugar                          NaN
#
#                  phone  age      gender  course              department  \
# 0       +91-8923923126   17        Male     BCA  Information Technology
# 1      (+918179323023)   25  Non-Binary     M.E                Chemical
# ...

# %% [markdown]
# #### cleaning state data

# %%
df["state"] = df["state"].apply(lambda x: x.title().strip())

# %%
df["state"].unique()
# Out:
# array(['Ts', 'Kerala', 'Tamil Nadu', 'Rajasthan', 'Delhi', 'Rj', 'Dl',
#        'West Bengal', 'Mh', 'Telangana', 'Tn', 'Wb', 'Gujarat',
#        'Karnataka', 'Kl', 'Uttar Pradesh', 'Maharashtra', 'Gj', 'Up',
#        'Ka'], dtype=object)

# %%
def state_1(x):
    if x in ["Tn"]:
       return "Tamil Nadu"
    elif x in ["Rj"]:
        return "Rajasthan"
    elif x in ["Dl"]:
        return "Delhi"
    elif x in "Ts":
        return "Telangana"
    elif x in "Wb":
        return "West Bengal"
    elif x in "Mh":
        return "Maharashtra"
    elif x in "Gj":
        return  "Gujarat"
    elif x in "Up":
        return "Uttar Pradesh"
    elif x in "Ka":
        return "Karnataka"
    elif x in "Kl":
        return "Kerala"
    else:
        return x

# %%
df["state"]=df["state"].apply(state_1)

# %% [markdown]
# ### Age column cleaning

# %%
df["age"].unique()
# Out:
# array([ 17,  25,  21,  19,  18,  23,  27,  20,  28, -26, -18,  26,  22,
#         70,  24,  73, -22, -19,  78,  74, -23, -20, -28,  72,  68,  69,
#        -17,  77, -27, -25, -24, -21,  75])

# %%
df["age"].dtype
# Out:
# dtype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      510 non-null    object
#  1   name            510 non-null    object
#  2   email           466 non-null    object
#  3   phone           460 non-null    object
#  4   age             510 non-null    int64
#  5   gender          510 non-null    object
#  6   course          510 non-null    object
#  7   department      510 non-null    object
#  8   semester        510 non-null    int64
#  9   cgpa            480 non-null    float64
#  10  attendance      468 non-null    object
#  11  city            473 non-null    object
#  12  state           510 non-null    object
#  13  admission_date  510 non-null    object
#  14  fees_paid       510 non-null    object
#  15  hostel          510 non-null    object
# dtypes: float64(1), int64(2), object(13)
# ...

# %%
#  age=df["age"].astype(float)

# %%
# age.unique()

# %%
# age=abs(age)

# %%
# age.unique()

# %%
def age_1(x):
    x = abs(x)
    return x

# %%
df["age"]=df["age"].apply(age_1)

# %%
df.sample(2)
# Out:
#       student_id         name                  email          phone  age  \
# 500  STU20226752  Xalak Saraf   GIRISH80@EXAMPLE.ORG  +919740148902   28
# 110  STU20233725     Ryan Das  ethanseth@example.org     7155188442   28
#
#     gender  course        department  semester  cgpa attendance      city  \
# 500  Other  M.Tech       Electronics         2  5.73        NaN      Pune
# 110  Woman  B.Tech  Computer Science         6  8.98      57.6%  Mirzapur
#
#            state admission_date fees_paid hostel
# 500       Kerala     16-08-2022      TRUE    Yes
# 110  West Bengal     2025-03-10        no    Yes

# %% [markdown]
# #### cleaning Gender colunm

# %%
df["gender"].unique()
# Out:
# array(['Male', 'Non-Binary', 'Female', 'Man', 'O', 'M', 'female', 'male',
#        'other', 'F', 'Other', 'MALE', 'Woman', 'FEMALE'], dtype=object)

# %%
def gender_clean(y):
    x= str(y).upper()
    if x in ["M","MALE","MAN"]:
        return "Male"
    elif x in ["F", "WOMAN"]:
        return "Female"
    else:
        return "OTHER"

# %%
df["gender"]=df["gender"].apply(gender_clean)

# %%
df["gender"].unique()
# Out:
# array(['Male', 'OTHER', 'Female'], dtype=object)

# %%
df.head()
# Out:
#     student_id            name                        email  \
# 0  STU20238485     Yug Sanghvi    urvichauhan@example.net
# 1  STU20206913  Patrick Prasad        krishhora@example.com
# 2  STU20237737     Teerth Mody      shethvinaya@example.org
# 3  STU20212477       Triya Bir     kiberaksha@example.org
# 4  STU20221620    Chasmum Rana                          NaN
#
#                phone  age gender  course              department  semester  \
# 0     +91-8923923126   17   Male     BCA  Information Technology         7
# 1    (+918179323023)   25  OTHER     M.E                Chemical         6
# 2      (00975451052)   21  OTHER     MCA                Chemical         5
# 3                NaN   19   Male     M.E             Electronics         6
# 4  +91-+914287572158   18   Male  B.Tech             Electronics         5
#
#     cgpa attendance       city       state admission_date fees_paid hostel
# 0   9.92       42.4    Panipat   Telangana     2022-07-01         1    Yes
# ...

# %%
df['gender'].unique()
# Out:
# array(['Male', 'OTHER', 'Female'], dtype=object)

# %% [markdown]
# ### Email cleaning

# %%
df["email"].unique()
# Out:
# array(['  urvichauhan@example.net  ', 'krishhora@example.com',
#        'shethvinaya@example.org', '  kiberaksha@example.org  ', nan,
#        '  cmammen@example.net  ', '  srinivasandalaja@example.org  ',
#        'RAJESHRICHAND@EXAMPLE.ORG', '  bosewriddhish@example.org  ',
#        'TARAAVI@EXAMPLE.ORG', 'daksheshkhanna@example.net',
#        'calebdatta@example.net', 'forumkarpe@example.com',
#        '  kotharinakul@example.com  ', 'ranabakhshi@example.net',
#        'fmorar@example.org', 'CHATURA15@EXAMPLE.COM',
#        'mason22@example.org', 'atwalteerth@example.net',
#        '  lshere@example.net  ', 'ekantika31@example.com',
#        'ekanshbalay@example.com', 'purohitishita@example.net',
#        'dattaaashi@example.net', 'anjali60@example.org',
#        'PRASHADZINAL@EXAMPLE.COM', 'upkaar49@example.org',
#        'ishwargade@example.com', 'choprahemangini@example.org',
#        '  balakrishnanfinn@example.org  ', 'vtandon@example.net',
# ...

# %%
df["email"]=df["email"].apply(lambda x:  x.lower().strip() if pd.notna(x) else x )

# %%
df.sample(6)
# Out:
#       student_id            name                    email              phone  \
# 70   STU20213589  Yoshita Pandit                      NaN      +915153814474
# 256  STU20235844      Finn Dugar   oscarborde@example.org  +91-+916797403447
# 65   STU20248973   Nidra Acharya    bhavini36@example.net         5777387214
# 329  STU20229027  Onkar Nadkarni       wgolla@example.net         8896792408
# 242  STU20218573   Radhika Dugar    uaggarwal@example.net        08281489325
# 224  STU20228353      Yatin Mall  jananisoman@example.net        04090034864
#
#      age gender  course              department  semester   cgpa attendance  \
# 70    22   Male     BCA  Information Technology         2   5.92       90.4
# 256   25   Male  M.Tech                   Civil         7   8.39       94.2
# 65    19   Male     B.E             Electronics         1   7.90       72.5
# 329   23  OTHER  M.Tech        Computer Science         6  13.42       61.3
# ...

# %%
df["course"].unique()
# Out:
# array(['BCA', 'M.E', 'MCA', 'B.Tech', 'B.E', 'M.Tech'], dtype=object)

# %%
df["department"].unique()
# Out:
# array(['Information Technology', 'Chemical', 'Electronics',
#        'Computer Science', 'Mechanical', 'Electrical', 'Civil'],
#       dtype=object)

# %%
df["cgpa"].unique()
# Out:
# array([ 9.92, 13.97,  5.76,  7.1 ,   nan,  5.06,  8.63,  8.13,  9.13,
#        -6.83,  6.58, 10.65,  7.27,  8.74,  8.89,  6.3 ,  9.89,  7.2 ,
#         8.91,  7.98,  9.12,  5.47,  9.7 , -8.83,  7.62,  7.73,  9.65,
#         9.96, -8.31,  9.16,  5.57, 14.85, 13.3 ,  7.17,  6.95,  9.15,
#         9.84,  8.97,  9.21,  9.  ,  8.54,  6.39,  9.91,  5.52,  6.93,
#         7.4 ,  7.06,  9.57,  5.81,  7.67,  8.2 ,  6.24,  6.75,  5.95,
#         8.93,  7.85,  6.46,  8.68,  8.25,  7.54,  7.91,  7.9 ,  6.86,
#         7.49,  7.88,  5.92,  8.37,  8.08,  7.43,  7.89,  7.32,  5.74,
#         7.07,  7.66,  9.63,  7.52,  9.71,  5.21,  5.55,  7.84,  7.13,
#         5.27, -7.2 ,  7.82, -9.04,  6.45,  8.76,  7.42,  5.79,  6.59,
#         5.53, -6.55, 13.48,  8.23,  8.01,  8.98,  9.32,  5.16,  5.32,
#         9.37, -9.87,  9.51,  5.7 , 11.79, 13.08,  7.09,  8.07,  9.07,
#         6.7 ,  9.62,  6.16,  6.42,  8.06,  7.29,  5.12, 14.46, 12.85,
# ...

# %%
# df["cgpa"].apply(lambda x:  x if pd.isna(x) else x, x=abs(x), x)

# %%
def cgpa_clean(x):
    # x.strip()
    if pd.isna(x):
        return x
    elif x > 10:
        x= x-5 
    x=abs(x)
    return x

# %%
df["cgpa"]=df["cgpa"].apply(cgpa_clean)

# %%
df["cgpa"].unique()
# Out:
# array([ 9.92,  8.97,  5.76,  7.1 ,   nan,  5.06,  8.63,  8.13,  9.13,
#         6.83,  6.58,  5.65,  7.27,  8.74,  8.89,  6.3 ,  9.89,  7.2 ,
#         8.91,  7.98,  9.12,  5.47,  9.7 ,  8.83,  7.62,  7.73,  9.65,
#         9.96,  8.31,  9.16,  5.57,  9.85,  8.3 ,  7.17,  6.95,  9.15,
#         9.84,  9.21,  9.  ,  8.54,  6.39,  9.91,  5.52,  6.93,  7.4 ,
#         7.06,  9.57,  5.81,  7.67,  8.2 ,  6.24,  6.75,  5.95,  8.93,
#         7.85,  6.46,  8.68,  8.25,  7.54,  7.91,  7.9 ,  6.86,  7.49,
#         7.88,  5.92,  8.37,  8.08,  7.43,  7.89,  7.32,  5.74,  7.07,
#         7.66,  9.63,  7.52,  9.71,  5.21,  5.55,  7.84,  7.13,  5.27,
#         7.82,  9.04,  6.45,  8.76,  7.42,  5.79,  6.59,  5.53,  6.55,
#         8.48,  8.23,  8.01,  8.98,  9.32,  5.16,  5.32,  9.37,  9.87,
#         9.51,  5.7 ,  6.79,  7.09,  8.07,  9.07,  6.7 ,  9.62,  6.16,
#         6.42,  8.06,  7.29,  5.12,  9.46,  7.25,  6.82,  7.37,  8.41,
# ...

# %%
df.sample(10)
# Out:
#       student_id                  name                         email  \
# 335  STU20249369     Yashasvi Choudhry      pradhanaashi@example.net
# 469  STU20236026  Oliver Bhattacharyya         misrabina@example.com
# 183  STU20246804       Manbir Chaudhry  chaudhuribhavika@example.net
# 409  STU20222770         Lakshmi Saran        oscarsoman@example.org
# 399  STU20249709        Guneet Purohit     kritikacheema@example.org
# 21   STU20201771       Ekavir Bhargava       ekanshbalay@example.com
# 129  STU20216147    Vaishnavi Sengupta             yug48@example.com
# 219  STU20235043            Warjas Ben                           NaN
# 46   STU20217730         Jhalak Sarkar           ysarraf@example.com
# 19   STU20201977       Gautam Tripathi            lshere@example.net
#
#                  phone  age  gender  course              department  semester  \
# 335         5101749075   21    Male     MCA              Electrical         6
# ...

# %%
df["cgpa"].unique()
# Out:
# array([ 9.92,  8.97,  5.76,  7.1 ,   nan,  5.06,  8.63,  8.13,  9.13,
#         6.83,  6.58,  5.65,  7.27,  8.74,  8.89,  6.3 ,  9.89,  7.2 ,
#         8.91,  7.98,  9.12,  5.47,  9.7 ,  8.83,  7.62,  7.73,  9.65,
#         9.96,  8.31,  9.16,  5.57,  9.85,  8.3 ,  7.17,  6.95,  9.15,
#         9.84,  9.21,  9.  ,  8.54,  6.39,  9.91,  5.52,  6.93,  7.4 ,
#         7.06,  9.57,  5.81,  7.67,  8.2 ,  6.24,  6.75,  5.95,  8.93,
#         7.85,  6.46,  8.68,  8.25,  7.54,  7.91,  7.9 ,  6.86,  7.49,
#         7.88,  5.92,  8.37,  8.08,  7.43,  7.89,  7.32,  5.74,  7.07,
#         7.66,  9.63,  7.52,  9.71,  5.21,  5.55,  7.84,  7.13,  5.27,
#         7.82,  9.04,  6.45,  8.76,  7.42,  5.79,  6.59,  5.53,  6.55,
#         8.48,  8.23,  8.01,  8.98,  9.32,  5.16,  5.32,  9.37,  9.87,
#         9.51,  5.7 ,  6.79,  7.09,  8.07,  9.07,  6.7 ,  9.62,  6.16,
#         6.42,  8.06,  7.29,  5.12,  9.46,  7.25,  6.82,  7.37,  8.41,
# ...

# %%
df["cgpa"]=df["cgpa"].astype(float)

# %%
df["cgpa"].unique()
# Out:
# array([ 9.92,  8.97,  5.76,  7.1 ,   nan,  5.06,  8.63,  8.13,  9.13,
#         6.83,  6.58,  5.65,  7.27,  8.74,  8.89,  6.3 ,  9.89,  7.2 ,
#         8.91,  7.98,  9.12,  5.47,  9.7 ,  8.83,  7.62,  7.73,  9.65,
#         9.96,  8.31,  9.16,  5.57,  9.85,  8.3 ,  7.17,  6.95,  9.15,
#         9.84,  9.21,  9.  ,  8.54,  6.39,  9.91,  5.52,  6.93,  7.4 ,
#         7.06,  9.57,  5.81,  7.67,  8.2 ,  6.24,  6.75,  5.95,  8.93,
#         7.85,  6.46,  8.68,  8.25,  7.54,  7.91,  7.9 ,  6.86,  7.49,
#         7.88,  5.92,  8.37,  8.08,  7.43,  7.89,  7.32,  5.74,  7.07,
#         7.66,  9.63,  7.52,  9.71,  5.21,  5.55,  7.84,  7.13,  5.27,
#         7.82,  9.04,  6.45,  8.76,  7.42,  5.79,  6.59,  5.53,  6.55,
#         8.48,  8.23,  8.01,  8.98,  9.32,  5.16,  5.32,  9.37,  9.87,
#         9.51,  5.7 ,  6.79,  7.09,  8.07,  9.07,  6.7 ,  9.62,  6.16,
#         6.42,  8.06,  7.29,  5.12,  9.46,  7.25,  6.82,  7.37,  8.41,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      510 non-null    object
#  1   name            510 non-null    object
#  2   email           466 non-null    object
#  3   phone           460 non-null    object
#  4   age             510 non-null    int64
#  5   gender          510 non-null    object
#  6   course          510 non-null    object
#  7   department      510 non-null    object
#  8   semester        510 non-null    int64
#  9   cgpa            480 non-null    float64
#  10  attendance      468 non-null    object
#  11  city            473 non-null    object
#  12  state           510 non-null    object
#  13  admission_date  510 non-null    object
#  14  fees_paid       510 non-null    object
#  15  hostel          510 non-null    object
# dtypes: float64(1), int64(2), object(13)
# ...

# %%
df.head(10)
# Out:
#     student_id             name                         email  \
# 0  STU20238485      Yug Sanghvi       urvichauhan@example.net
# 1  STU20206913   Patrick Prasad         krishhora@example.com
# 2  STU20237737      Teerth Mody       shethvinaya@example.org
# 3  STU20212477        Triya Bir        kiberaksha@example.org
# 4  STU20221620     Chasmum Rana                           NaN
# 5  STU20229728      Hardik Suri           cmammen@example.net
# 6  STU20243967    William Chana  srinivasandalaja@example.org
# 7  STU20204073  Anjali Sengupta     rajeshrichand@example.org
# 8  STU20244726     Dhriti Chana     bosewriddhish@example.org
# 9  STU20244389      Hardik Bera           taraavi@example.org
#
#                phone  age gender  course              department  semester  \
# 0     +91-8923923126   17   Male     BCA  Information Technology         7
# 1    (+918179323023)   25  OTHER     M.E                Chemical         6
# ...

# %% [markdown]
# ### cleaning fees_paid column

# %%
df["fees_paid"].unique()
# Out:
# array(['1', 'N', 'Yes', '0', 'False', 'no', 'yes', 'No', 'TRUE', 'FALSE',
#        'True', 'Y'], dtype=object)

# %%
def fees_clean(x):
    x = x.upper()
    if x in ["1","YES","TRUE"]:
        return "YES"
    else:
        return "NO"

# %%
df["fees_paid"]=df["fees_paid"].apply(fees_clean)

# %%
df["fees_paid"].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
df.head(10)
# Out:
#     student_id             name                         email  \
# 0  STU20238485      Yug Sanghvi       urvichauhan@example.net
# 1  STU20206913   Patrick Prasad         krishhora@example.com
# 2  STU20237737      Teerth Mody       shethvinaya@example.org
# 3  STU20212477        Triya Bir        kiberaksha@example.org
# 4  STU20221620     Chasmum Rana                           NaN
# 5  STU20229728      Hardik Suri           cmammen@example.net
# 6  STU20243967    William Chana  srinivasandalaja@example.org
# 7  STU20204073  Anjali Sengupta     rajeshrichand@example.org
# 8  STU20244726     Dhriti Chana     bosewriddhish@example.org
# 9  STU20244389      Hardik Bera           taraavi@example.org
#
#                phone  age gender  course              department  semester  \
# 0     +91-8923923126   17   Male     BCA  Information Technology         7
# 1    (+918179323023)   25  OTHER     M.E                Chemical         6
# ...

# %% [markdown]
# ####  cleaning  admission_date column

# %%
df["admission_date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 510 entries, 0 to 509
# Series name: admission_date
# Non-Null Count  Dtype
# --------------  -----
# 510 non-null    object
# dtypes: object(1)
# memory usage: 4.1+ KB

# %%
from datetime import datetime

# %%
def adddmission(x):
    return datetime.strptime(x, "%Y-%m-%d")

# %%
df["admission_date"].apply(adddmission)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 df["admission_date"].apply(adddmission)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      510 non-null    object
#  1   name            510 non-null    object
#  2   email           466 non-null    object
#  3   phone           460 non-null    object
#  4   age             510 non-null    int64
#  5   gender          510 non-null    object
#  6   course          510 non-null    object
#  7   department      510 non-null    object
#  8   semester        510 non-null    int64
#  9   cgpa            480 non-null    float64
#  10  attendance      468 non-null    object
#  11  city            473 non-null    object
#  12  state           510 non-null    object
#  13  admission_date  510 non-null    object
#  14  fees_paid       510 non-null    object
#  15  hostel          510 non-null    object
# dtypes: float64(1), int64(2), object(13)
# ...

# %% [markdown]
# ### handling null valuse

# %%
df.isnull().sum()
# Out:
# student_id         0
# name               0
# email             44
# phone             50
# age                0
# gender             0
# course             0
# department         0
# semester           0
# cgpa              30
# attendance        42
# city              37
# state              0
# admission_date     0
# fees_paid          0
# hostel             0
# dtype: int64

# %%
df["cgpa"]=df["cgpa"].fillna(0)

# %%
df.isnull().sum()
# Out:
# student_id         0
# name               0
# email             44
# phone             50
# age                0
# gender             0
# course             0
# department         0
# semester           0
# cgpa               0
# attendance        42
# city              37
# state              0
# admission_date     0
# fees_paid          0
# hostel             0
# dtype: int64

# %%
df["attendance"]=df["attendance"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df["attendance"]=df["attendance"].astype(float)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# ...

# %%
def attendance(x):
   
    if pd.isna(x):
        return x
    elif  x > 100:
        return 100.0
    # x= x.replace("%"," ")
    # return x

# %%
df["attendance"].apply(attendance)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df["attendance"].apply(attendance)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# ...

# %% [markdown]
# ## handling null valuse

# %%
df.isnull().sum()
# Out:
# student_id         0
# name               0
# email             44
# phone             50
# age                0
# gender             0
# course             0
# department         0
# semester           0
# cgpa              30
# attendance        42
# city              37
# state              0
# admission_date     0
# fees_paid          0
# hostel             0
# dtype: int64

# %%
df["cgpa"]=df["cgpa"].fillna(0.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      510 non-null    object
#  1   name            510 non-null    object
#  2   email           466 non-null    object
#  3   phone           460 non-null    object
#  4   age             510 non-null    int64
#  5   gender          510 non-null    object
#  6   course          510 non-null    object
#  7   department      510 non-null    object
#  8   semester        510 non-null    int64
#  9   cgpa            480 non-null    float64
#  10  attendance      468 non-null    object
#  11  city            473 non-null    object
#  12  state           510 non-null    object
#  13  admission_date  510 non-null    object
#  14  fees_paid       510 non-null    object
#  15  hostel          510 non-null    object
# dtypes: float64(1), int64(2), object(13)
# ...

# %%
df.isnull().sum()
# Out:
# student_id         0
# name               0
# email             44
# phone             50
# age                0
# gender             0
# course             0
# department         0
# semester           0
# cgpa               0
# attendance        42
# city              37
# state              0
# admission_date     0
# fees_paid          0
# hostel             0
# dtype: int64

# %%
df["attendance"].unique()
# Out:
# array(['42.4', '43.5', '51.3%', '87.1', '74.5', '65.2', '73.5', '85.6',
#        '94.6', nan, '64.0%', '46.4', '72.0', '69.3', '81.4%', '50.5',
#        '58.9%', '100.2', '68.1', '84.7', '63.1', '69.7%', '100.4',
#        '82.0%', '74.6', '83.3%', '90.1', '52.5', '57.7', '90.9', '86.3%',
#        '60.8', '68.2%', '40.9', '101.2', '47.1', '73.3', '59.6%', '70.5%',
#        '62.8', '96.8', '67.6', '52.9', '87.3%', '79.8', '86.9%', '90.6',
#        '113.8', '58.6', '64.4', '76.0', '101.4', '57.1%', '89.2', '58.0',
#        '51.7', '53.9', '80.6', '91.1%', '72.1%', '72.5', '95.1', '83.0',
#        '99.5%', '85.8', '90.4', '40.2', '99.0', '55.5', '70.4', '66.3',
#        '56.1', '66.5', '79.9', '89.4', '63.3%', '96.7%', '43.0%', '92.2%',
#        '71.4', '46.4%', '72.7', '99.4%', '59.9', '88.0', '53.8', '69.1',
#        '93.0', '57.2', '44.0', '69.3%', '83.7%', '60.9', '98.5', '76.7',
#        '86.1', '48.3', '68.9', '75.5%', '99.8', '93.2', '57.6%', '89.5',
# ...

# %%
def attendance_clean(x):
    if pd.isna(x):
        return x
    y =str(x).replace("%"," ").strip()

# %%
def clean_attendance(att):
    if pd.isna(att):
        return att
    # Convert to string and remove % if present
    att_str = str(att).replace('%', '').strip()
    # Convert to float
    att_value = float(att_str)
    # Cap at 100
    if att_value > 100:
        att_value = 100.0
    # Round to 1 decimal
    return round(att_value, 1)

# %% [markdown]
# df['attendance'] = df['attendance'].apply(clean_attendance)
# df["attendance"]

# %%
df["attendance"].apply(attendance_clean)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 505   NaN
# 506   NaN
# 507   NaN
# 508   NaN
# 509   NaN
# Name: attendance, Length: 510, dtype: float64

# %%
df['attendance'] = df['attendance'].apply(clean_attendance)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_10692\3862463479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['attendance'] = df['attendance'].apply(clean_attendance)

# %%
df["attendance"].unique()
# Out:
# array([ 42.4,  43.5,  51.3,  87.1,  74.5,  65.2,  73.5,  85.6,  94.6,
#          nan,  64. ,  46.4,  72. ,  69.3,  81.4,  50.5,  58.9, 100. ,
#         68.1,  84.7,  63.1,  69.7,  82. ,  74.6,  83.3,  90.1,  52.5,
#         57.7,  90.9,  86.3,  60.8,  68.2,  40.9,  47.1,  73.3,  59.6,
#         70.5,  62.8,  96.8,  67.6,  52.9,  87.3,  79.8,  86.9,  90.6,
#         58.6,  64.4,  76. ,  57.1,  89.2,  58. ,  51.7,  53.9,  80.6,
#         91.1,  72.1,  72.5,  95.1,  83. ,  99.5,  85.8,  90.4,  40.2,
#         99. ,  55.5,  70.4,  66.3,  56.1,  66.5,  79.9,  89.4,  63.3,
#         96.7,  43. ,  92.2,  71.4,  72.7,  99.4,  59.9,  88. ,  53.8,
#         69.1,  93. ,  57.2,  44. ,  83.7,  60.9,  98.5,  76.7,  86.1,
#         48.3,  68.9,  75.5,  99.8,  93.2,  57.6,  89.5,  78.5,  65.1,
#         72.4,  51. ,  52.8,  95.2,  93.9,  96.2,  82.4,  47. ,  73.8,
#         84.6,  95.7,  71. ,  91.6,  51.2,  80.1,  49.2,  80. ,  60.5,
# ...

# %%
df.isnull().sum()
# Out:
# student_id         0
# name               0
# email             44
# phone             50
# age                0
# gender             0
# course             0
# department         0
# semester           0
# cgpa               0
# attendance        42
# city              37
# state              0
# admission_date     0
# fees_paid          0
# hostel             0
# dtype: int64

# %%
df["attendance"]=df["attendance"].fillna(0.0)

# %%
df.isnull().sum()
# Out:
# student_id         0
# name               0
# email             44
# phone             50
# age                0
# gender             0
# course             0
# department         0
# semester           0
# cgpa               0
# attendance        42
# city              37
# state              0
# admission_date     0
# fees_paid          0
# hostel             0
# dtype: int64

# %%
# df["city"]=df["city"].fillna(df["city"].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df["city"]=df["city"].fillna(df["city"].mode()[0])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# ...

# %%
df.isnull().sum()
# Out:
# student_id         0
# name               0
# email             44
# phone             50
# age                0
# gender             0
# course             0
# department         0
# semester           0
# cgpa               0
# attendance        42
# city              37
# state              0
# admission_date     0
# fees_paid          0
# hostel             0
# dtype: int64

# %%
df["city"].mode()
# Out:
# Series([], Name: city, dtype: object)

# %%
df=df.dropna()

# %%
df
# Out:
#       student_id             name                         email  \
# 0    STU20238485      Yug Sanghvi       urvichauhan@example.net
# 1    STU20206913   Patrick Prasad         krishhora@example.com
# 2    STU20237737      Teerth Mody       shethvinaya@example.org
# 5    STU20229728      Hardik Suri           cmammen@example.net
# 6    STU20243967    William Chana  srinivasandalaja@example.org
# ..           ...              ...                           ...
# 499  STU20219952  Indira Yohannan        hardikbasu@example.org
# 502  STU20232604     Pranav Lanka       chopraradha@example.com
# 505  STU20243430   Jacob Merchant         timothy32@example.com
# 506  STU20241752    Atharv Parmer         soodkrish@example.net
# 508  STU20206410      Anjali Dube           lparmar@example.org
#
#                phone  age gender  course              department  semester  \
# 0     +91-8923923126   17   Male     BCA  Information Technology         7
# ...

# %%
df.shape
# Out:
# (353, 16)

# %%
df.sample(10)
# Out:
#       student_id               name                        email  \
# 11   STU20223526        Nirja Bains       calebdatta@example.net
# 149  STU20234365       Qadim Suresh       dasikshita@example.org
# 191  STU20221833     Pahal Chaudhry       advikatoor@example.org
# 124  STU20239294  Tripti Narasimhan       deolaarnav@example.net
# 230  STU20216370      Tamanna Parsa  chanderchandani@example.com
# 320  STU20241857       Gaurangi Rai            ria56@example.net
# 171  STU20221832          Upma Bahl      pallaudarsh@example.net
# 112  STU20211512        Aachal Kota        advikdada@example.org
# 281  STU20227544        Siya Barman     shettybimala@example.net
# 273  STU20219095        Mitali Bose       nicholas93@example.net
#
#                  phone  age  gender  course              department  semester  \
# 11          2280920242   23   OTHER     MCA             Electronics         7
# 149    (+916794975679)   28  Female     M.E              Mechanical         2
# ...

# %%
# Solution 1: Using string replacement
def clean_phone(phone):
    if pd.isna(phone):
        return phone
    # Convert to string and remove all non-digit characters
    phone_str = str(phone)
    digits = ''.join(filter(str.isdigit, phone_str))
    # Take last 10 digits (removes country code if present)
    return digits[-10:] if len(digits) >= 10 else digits

df['phone'] = df['phone'].apply(clean_phone)

# Alternative solution using replace
# df['phone'] = df['phone'].apply(lambda x: ''.join(filter(str.isdigit, str(x)))[-10:] if pd.notna(x) else x)

print("Sample cleaned phone numbers:")
print(df['phone'].head(10))
print(f"\nAll phone numbers have 10 digits: {df['phone'].dropna().apply(lambda x: len(str(x)) == 10).all()}")
# Out:
# Sample cleaned phone numbers:
# 0     8923923126
# 1     8179323023
# 2     0975451052
# 5     3773515850
# 6     7990772625
# 7     5060685361
# 8     9014870682
# 10    0653331537
# 11    2280920242
# 12    3785477725
# Name: phone, dtype: object
#
# All phone numbers have 10 digits: True
# C:\Users\pavan\AppData\Local\Temp\ipykernel_10692\3211792548.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phone'] = df['phone'].apply(clean_phone)

# %%
df
# Out:
#       student_id             name                         email       phone  \
# 0    STU20238485      Yug Sanghvi       urvichauhan@example.net  8923923126
# 1    STU20206913   Patrick Prasad         krishhora@example.com  8179323023
# 2    STU20237737      Teerth Mody       shethvinaya@example.org  0975451052
# 5    STU20229728      Hardik Suri           cmammen@example.net  3773515850
# 6    STU20243967    William Chana  srinivasandalaja@example.org  7990772625
# ..           ...              ...                           ...         ...
# 499  STU20219952  Indira Yohannan        hardikbasu@example.org  3243298395
# 502  STU20232604     Pranav Lanka       chopraradha@example.com  5698169340
# 505  STU20243430   Jacob Merchant         timothy32@example.com  7956878339
# 506  STU20241752    Atharv Parmer         soodkrish@example.net  7526772233
# 508  STU20206410      Anjali Dube           lparmar@example.org  0837081647
#
# ...

# %%
df.to_csv("cleaned_file.csv", index=False)

# %%
# df.to_csv("cleaned_file.csv", index=False)
