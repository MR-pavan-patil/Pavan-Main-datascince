# %%
number=[10,20,30,"pavan",10.2]

# %%
type(number)
# Out:
# list

# %%
number.index(20)
# Out:
# 1

# %%
names=("pavan","sanju",10 ,"revan")

# %%
type(names)
# Out:
# tuple

# %%
s1={1,3,34,5,6,7}

# %%
type(s1)
# Out:
# set

# %%
stu={'name':'pavan',
    'age':21,
    'college':'srec'}

# %%
type(stu)
# Out:
# dict

# %%
number=[1,2,3,5,6,7]

# %%
number.append(8)

# %%
number
# Out:
# [1, 2, 3, 5, 6, 7, 8]

# %%
number.insert(1,1)

# %%
number
# Out:
# [1, 1, 2, 3, 5, 6, 7, 8]

# %%
number.count(1)
# Out:
# 2

# %%
number
# Out:
# [1, 1, 2, 3, 5, 6, 7, 8]

# %%
number.pop(1)
# Out:
# 1

# %%
number
# Out:
# [1, 2, 3, 5, 6, 7, 8]

# %%
number.remove(1)

# %%
number
# Out:
# [2, 3, 5, 6, 7, 8]

# %%
num2=number.copy()

# %%
num2
# Out:
# [2, 3, 5, 6, 7, 8]

# %%
names=("pavan" ,"rahul", "sandya","nilesh","pavan")

# %%
names.count("pavan")
# Out:
# 2

# %%
names.index("rahul")
# Out:
# 1

# %%
d1={'name':'pavan',
    'age':21,
    'college':'srec'}

# %%
d1.keys()
# Out:
# dict_keys(['name', 'age', 'college'])

# %%
d1.values()
# Out:
# dict_values(['pavan', 21, 'srec'])

# %%
d1.items()
# Out:
# dict_items([('name', 'pavan'), ('age', 21), ('college', 'srec')])

# %%
d1.get('age')
# Out:
# 21

# %%
d1.update({'age':22})
d1
# Out:
# {'name': 'pavan', 'age': 22, 'college': 'srec'}

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    1/0
except :
    print("hey you cant divide a number by zero")
# Out:
# hey you cant divide a number by zero

# %%
a=10
b="20"
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 a=10
#       2 b="20"
# ----> 3 a+b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    1/0
except :

    print("you cant add int and str")
# Out:
# you cant add int and str

# %%
name=int(input("enter your age:"))

# %%
try:
# Out:
#   Cell In[9], line 1
#     try:
#         ^
# SyntaxError: incomplete input
