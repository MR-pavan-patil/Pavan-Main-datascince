# %%
from datetime import datetime ,timedelta

# %%
now = datetime.now()

# %%
type(now)
# Out:
# datetime.datetime

# %%
now
# Out:
# datetime.datetime(2025, 11, 14, 15, 39, 37, 459938)

# %%
# datetime_str=now.strftime("%A")

# %%
# datetime_str

# %%
date_str=now.strftime("%Y-%m-%d %H:%M:%S")

# %%
type(date_str)
# Out:
# str

# %%
date_str
# Out:
# '2025-11-14 15:39:37'

# %%
now =datetime.strptime(date_str, "%Y-%m-%d %H:%M:%S")

# %%
now
# Out:
# datetime.datetime(2025, 11, 14, 15, 39, 37)

# %%
now+timedelta(days=5)
# Out:
# datetime.datetime(2025, 11, 19, 15, 39, 37)

# %%
now+timedelta(hours=5)
# Out:
# datetime.datetime(2025, 11, 14, 20, 39, 37)
