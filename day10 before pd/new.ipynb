# %%
x=10
y=20
x+y
# Out:
# 30

# %%
#formated 

name= int(input("enter your name:"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 #formated
# ----> 3 name= int(input("enter your name:"))
#
# ValueError: invalid literal for int() with base 10: 'pavan'

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
name
# Out:
# str
