# %%
# !pip install numby
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\pavan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install numpy

import numpy as np

a=np.array([1,2,3,4])
b=np.array([5,6,7,8])

# %%
a+b
# Out:
# array([ 6,  8, 10, 12])

# %%
np.sum(a)
# Out:
# np.int64(10)
