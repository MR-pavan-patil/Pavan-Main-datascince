# %%
# pavan=[1, 2, 3, 4, 5]
# pavan.append(6)
# pavan.insert(2,5)
# pavan.count(5)
# pavan.extend([6,7,8])
# pavan.sort()
# pavan.pop(2)
# pavan.index(4)
# sai=pavan.copy() 
# pavan.reverse()
# pavan.remove(5)

pavan
# Out:
# (1, 2, 3, 4, 5, 5, 5, 5)

# %%
pavan.index(4)
# Out:
# 3

# %%
pavan.pop(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 pavan.pop(2)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
pavan.count(5)
# Out:
# 1

# %%
pavan.clear()

# %%
pavan
# Out:
# []

# %%
# --- IGNORE --- now tuple

# %%
pavan=(1,2,3,4,5,5,5,5)

# %%
pavan.count(5)
# Out:
# 4

# %%
pavan.index(5)
# Out:
# 4

# %%
# now dictionary

# %%
stu={
    "name":"pavan",
    "age":21,
    "college":"satyam",
    "marks":98
}
stu.keys()
stu.values()
stu.items()
stu.get("name")
stu.update({"age":22})
stu.pop("marks")
stu.update({"branch":"cse"})
stu.popitem()
# stu.clear()

stu
# Out:
# {'name': 'pavan', 'age': 22, 'college': 'satyam'}

# %%
number=[1,2,3,4,5]


number
# Out:
# [1, 2, 3, 4, 5]

# %%
number[1:4]
# Out:
# [2, 3, 4]

# %%
number[::2] # step size 
number[::-1] # reverse the list
number[1:4:2] # start:end:step size
number[::3] # step size 3
number[1::3] # start from index 1 and step size 3
number[1:5:3] # start from index 1 to index 4 and step size 3
number[::4] # step size 4
number[1::4] # start from index 1 and step size 4
number[1:5:4] # start from index 1 to index 4 and step size 4
number[::5] # step size 5
# Out:
# [1]

# %%
def greet(name):
    print(f"hello {name} wellcome to py!")

# %%
greet("sai")
# Out:
# hello sai wellcome to py!

# %%
def tammma():
    print("hello tamma good morning ")

# %%
tammma()
# Out:
# hello tamma good morning

# %%
Name=input("enter a last name" )
Last=input("enter a last name" )
def fullname(name,last):
    print(f" well come back {Name} {Last} ")

# %%
fullname(Name,Last)
# Out:
#  well come back pavan patil

# %%
def add(a,b):
    # add=a+b
    return a+b

# %%
add(10,20)
# Out:
# 30

# %%
def calculaton(a,b):
    add=a+b
    yield
    sub=a-b
    yield
    mul=a*b
    yield
    div=a/b
    yield

    return add,sub,mul,div

# %%
calculaton(10,20)
# Out:
# <generator object calculaton at 0x000002854551E440>

# %%
for i in calculaton:
    print(calculaton)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 for i in calculaton:
#       2     print(calculaton)
#
# TypeError: 'function' object is not iterable

# %%
# def addd(a,b):
#     return a+b

# %%
addd=lambda a,b :a+b

# %%
addd(10,30)
# Out:
# 40

# %%
m=int(input("enter a number to check number is positive or nagetive number"))
if m>=0:
    print(f"{m} positive number")
else:
    print(f"{m} nagetive number")
# Out:
# 5 positive number

# %%
l1=[1,2,4,5,6,7,8,]
for i in l1:
    print(2)
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
