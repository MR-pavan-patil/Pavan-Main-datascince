# %%
x=10
y=20
print(x+y)
# Out:
# 30

# %%
print("pavan")
# Out:
# pavan

# %%
for i in range(1, 101):
    print(f" 😘  ")
# Out:
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
#  😘
